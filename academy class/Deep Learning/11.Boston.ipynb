# %% [markdown]
# # 모두의 딥러닝 15장_선형 회귀 적용하기
# ## 보스턴 집값 예측하기
#
# - 회귀문제
# - 이진분류에서는 0과 1 사이의 값을 구해야 하기 떄문에 sigmoid 를 썼는데
# - 이번 문제는 출력 자체를 값으로 받기 떄문에 activation 함수를 쓰지 않는다.
#
# - 분류 문제는 맞냐 안맞냐 이므로 퍼센터고 나온다
# - 회귀 문제는 정답과 출력 사이의 차이값이 나오므로 퍼센터가 아니가 존재는 숫재이다. (실제 값의 차이, 집값의 차이)
#
# - evaulate: 정확도 츣

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
seed = 0
np.random.seed(seed)
tf.random.set_seed(1)

# %% [markdown]
# 자료가 콤마가 아니라 스페이스로 구분되어 있다.

# %%
df = pd.read_csv('data/housing.csv', delim_whitespace=True)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   0.00632  505 non-null    float64
#  1   18.00    505 non-null    float64
#  2   2.310    505 non-null    float64
#  3   0        505 non-null    int64
#  4   0.5380   505 non-null    float64
#  5   6.5750   505 non-null    float64
#  6   65.20    505 non-null    float64
#  7   4.0900   505 non-null    float64
#  8   1        505 non-null    int64
#  9   296.0    505 non-null    float64
#  10  15.30    505 non-null    float64
#  11  396.90   505 non-null    float64
#  12  4.98     505 non-null    float64
#  13  24.00    505 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.4 KB
# None

# %%
print(df.head())
# 맨 뒤가 가격이 될 것이다.
# Out:
#    0.00632  18.00  2.310  0  0.5380  6.5750  65.20  4.0900  1  296.0  15.30  \
# 0  0.02731    0.0   7.07  0   0.469   6.421   78.9  4.9671  2  242.0   17.8
# 1  0.02729    0.0   7.07  0   0.469   7.185   61.1  4.9671  2  242.0   17.8
# 2  0.03237    0.0   2.18  0   0.458   6.998   45.8  6.0622  3  222.0   18.7
# 3  0.06905    0.0   2.18  0   0.458   7.147   54.2  6.0622  3  222.0   18.7
# 4  0.02985    0.0   2.18  0   0.458   6.430   58.7  6.0622  3  222.0   18.7
#
#    396.90  4.98  24.00
# 0  396.90  9.14   21.6
# 1  392.83  4.03   34.7
# 2  394.63  2.94   33.4
# 3  396.90  5.33   36.2
# 4  394.12  5.21   28.7

# %%
dataset = df.values
X = dataset[:, :13]
Y = dataset[:, 13]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.3, random_state=seed)

# %%
model = Sequential()

# %%
model.add(Dense(30, input_dim=13, activation = 'relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 30)                420
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 186
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 7
# ...
# Total params: 613
# Trainable params: 613
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=200, batch_size=10)
# Out:
# Train on 353 samples
# Epoch 1/200
# 353/353 [==============================] - 0s 1ms/sample - loss: 1575.8307
# Epoch 2/200
# 353/353 [==============================] - 0s 139us/sample - loss: 220.2275
# Epoch 3/200
# 353/353 [==============================] - 0s 131us/sample - loss: 154.0273
# Epoch 4/200
# 353/353 [==============================] - 0s 131us/sample - loss: 127.9800
# Epoch 5/200
# 353/353 [==============================] - 0s 124us/sample - loss: 111.6673
# Epoch 6/200
# 353/353 [==============================] - 0s 132us/sample - loss: 102.4303
# Epoch 7/200
# 353/353 [==============================] - 0s 137us/sample - loss: 94.8794
# Epoch 8/200
# 353/353 [==============================] - 0s 134us/sample - loss: 87.8654
# Epoch 9/200
# 353/353 [==============================] - 0s 124us/sample - loss: 82.6323
# Epoch 10/200
# 353/353 [==============================] - 0s 134us/sample - loss: 79.8865
# Epoch 11/200
# ...

# %%
y_prediction = model.predict(X_test).flatten()
# flatten : 납작ㅎ게 해주는 것, 2차원 배열을 1차원으로 만들어 준다

# %%
print(y_prediction)
# Out:
# [25.276253  34.305473  16.743166  30.307734  17.884806  24.373035
#  21.413954  11.307103  36.602905  19.789186  11.941984  23.58214
#  23.111755  29.65627   19.6445    30.474737  15.225358  44.21132
#  12.646604  22.954966  16.742348  10.119527  18.9824    17.99938
#  21.432653   8.661436  17.654377  12.713205  35.5182    36.598003
#  13.5796    19.916698  19.943787  22.389223  22.630394  20.866886
#  22.066828  14.3963375 21.350994  40.08105   23.758287  17.697847
#  12.358529  40.82977   23.027906  30.472858  11.946613  26.12049
#  11.923301  19.392662  15.431776  19.878477  18.453518   9.21953
#  19.572868  22.752089  22.654549  23.809536  15.849795  50.43678
#  24.374891  39.56313   16.585115  14.513501  35.01404   23.997635
#  20.8359    14.961449  14.218149  20.063444  14.709569  24.338663
#  34.65414   21.554392  22.66588   35.472317  11.151616  30.79971
#  20.210865  16.730268  34.67378   25.563501  28.304258  14.61833
# ...

# %%
for i in range(len(y_prediction)):
    label = y_test[i]
    prediction = y_prediction[i]
    print("실제가격: {:.3f}, 예상가격: {:.3f}".format(label, prediction))
# Out:
# 실제가격: 22.000, 예상가격: 25.276
# 실제가격: 43.800, 예상가격: 34.305
# 실제가격: 14.600, 예상가격: 16.743
# 실제가격: 32.700, 예상가격: 30.308
# 실제가격: 12.500, 예상가격: 17.885
# 실제가격: 23.100, 예상가격: 24.373
# 실제가격: 21.000, 예상가격: 21.414
# 실제가격: 5.600, 예상가격: 11.307
# 실제가격: 27.000, 예상가격: 36.603
# 실제가격: 17.000, 예상가격: 19.789
# 실제가격: 8.700, 예상가격: 11.942
# 실제가격: 21.900, 예상가격: 23.582
# 실제가격: 20.900, 예상가격: 23.112
# 실제가격: 26.700, 예상가격: 29.656
# 실제가격: 23.100, 예상가격: 19.645
# 실제가격: 29.000, 예상가격: 30.475
# 실제가격: 13.800, 예상가격: 15.225
# 실제가격: 50.000, 예상가격: 44.211
# 실제가격: 15.600, 예상가격: 12.647
# 실제가격: 24.700, 예상가격: 22.955
# 실제가격: 20.000, 예상가격: 16.742
# 실제가격: 10.500, 예상가격: 10.120
# 실제가격: 21.400, 예상가격: 18.982
# 실제가격: 19.400, 예상가격: 17.999
# 실제가격: 20.000, 예상가격: 21.433
# 실제가격: 8.500, 예상가격: 8.661
# 실제가격: 15.200, 예상가격: 17.654
# 실제가격: 13.900, 예상가격: 12.713
# 실제가격: 38.700, 예상가격: 35.518
# 실제가격: 31.500, 예상가격: 36.598
# 실제가격: 9.700, 예상가격: 13.580
# 실제가격: 19.300, 예상가격: 19.917
# 실제가격: 21.400, 예상가격: 19.944
# 실제가격: 20.600, 예상가격: 22.389
# ...
