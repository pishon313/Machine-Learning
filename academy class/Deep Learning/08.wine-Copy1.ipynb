# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
seed = 0
np.random.seed(seed)
tf.random.set_seed(3)

# %%
# df = df_pre.sample(frac=1)
df_pre = pd.read_csv('data/wine.csv')
df = df_pre.sample(frac=1)  # 전체 데이터에서 샘플을 가져온다. 1= 100%, 0.7 = 70%

# %%
print(df.head())
# Out:
#       7.4   0.7     0   1.9  0.076    11     34   0.9978  3.51  0.56   9.4  5  \
# 5315  6.3  0.18  0.24   3.4  0.053  20.0  119.0  0.99373  3.11  0.52   9.2  6
# 2423  7.0  0.21  0.37   7.2  0.042  36.0  167.0  0.99580  3.26  0.56   9.8  6
# 3517  7.3  0.22  0.50  13.7  0.049  56.0  189.0  0.99940  3.24  0.66   9.0  6
# 1622  6.6  0.27  0.41   1.3  0.052  16.0  142.0  0.99510  3.42  0.47  10.0  6
# 4060  8.3  0.25  0.33   2.5  0.053  12.0   72.0  0.99404  2.89  0.48   9.5  5
#
#       1
# 5315  0
# 2423  0
# 3517  0
# 1622  0
# 4060  0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6496 entries, 5315 to 2732
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   7.4     6496 non-null   float64
#  1   0.7     6496 non-null   float64
#  2   0       6496 non-null   float64
#  3   1.9     6496 non-null   float64
#  4   0.076   6496 non-null   float64
#  5   11      6496 non-null   float64
#  6   34      6496 non-null   float64
#  7   0.9978  6496 non-null   float64
#  8   3.51    6496 non-null   float64
#  9   0.56    6496 non-null   float64
#  10  9.4     6496 non-null   float64
#  11  5       6496 non-null   int64
#  12  1       6496 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 710.5 KB
# None

# %%
# 1: red wine, 0: white wine
# 1과 0을 구분하는 회귀, 바이너리 연산

# %%
dataset = df.values
print(dataset.dtype)
# 전체가 float 이므로 형변환 불필요
# Out:
# float64

# %%
X = dataset[:, :12]
Y = dataset[:, 12]

# %%
model = Sequential()
model.add(Dense(30, input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 30)                390
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                372
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 875
# Trainable params: 875
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 손실 함수 및 optimize 연걸
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
import os

MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR) :  # 같은 파일명이 존재하는지 확인
    os.mkdir(MODEL_DIR)   # 모델 생성
    

modelpath = './model/{epoch:02d}-{val_loss:.4f}.hdf5'
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True) # 체크포인트 생성, 무엇을 체크할 것인지 지정(mointor)

# monitor=val_loss : 무엇을 체크할 것인지 지정. val_loss 를 관찰하라는 뜻
# verbose=1 : 중간 과정을 계속 출력하라
# save_best_only=True : 모델이 향상될 때만 저장하라

# %%
model.fit(X, Y, validation_split=0.2, epochs=200, batch_size=200, verbose=0, callbacks=[checkpointer])

# validation_split=0.2 : 20% 를 뗴어놓고, 80%만 훈련시킨 후, 나머지 20% 를 validate을 해주고, 그때마다 그 값을 나타내 보여달라
# verbose=0 : 출력 값을 보이지 마라
# print("Accuracy:  %.4f" % (model.evaluate(X, Y)))
# Out:
# Epoch 00001: val_loss improved from inf to 0.37368, saving model to ./model/01-0.3737.hdf5
#
# Epoch 00002: val_loss improved from 0.37368 to 0.28212, saving model to ./model/02-0.2821.hdf5
#
# Epoch 00003: val_loss improved from 0.28212 to 0.23811, saving model to ./model/03-0.2381.hdf5
#
# Epoch 00004: val_loss improved from 0.23811 to 0.22935, saving model to ./model/04-0.2293.hdf5
#
# Epoch 00005: val_loss improved from 0.22935 to 0.22315, saving model to ./model/05-0.2231.hdf5
#
# Epoch 00006: val_loss improved from 0.22315 to 0.21993, saving model to ./model/06-0.2199.hdf5
#
# Epoch 00007: val_loss improved from 0.21993 to 0.21037, saving model to ./model/07-0.2104.hdf5
#
# Epoch 00008: val_loss improved from 0.21037 to 0.20698, saving model to ./model/08-0.2070.hdf5
#
# Epoch 00009: val_loss improved from 0.20698 to 0.20146, saving model to ./model/09-0.2015.hdf5
#
# Epoch 00010: val_loss improved from 0.20146 to 0.19567, saving model to ./model/10-0.1957.hdf5
#
# Epoch 00011: val_loss improved from 0.19567 to 0.18971, saving model to ./model/11-0.1897.hdf5
#
# Epoch 00012: val_loss improved from 0.18971 to 0.18945, saving model to ./model/12-0.1894.hdf5
#
# Epoch 00013: val_loss improved from 0.18945 to 0.18689, saving model to ./model/13-0.1869.hdf5
#
# Epoch 00014: val_loss improved from 0.18689 to 0.17885, saving model to ./model/14-0.1789.hdf5
#
# Epoch 00015: val_loss did not improve from 0.17885
#
# Epoch 00016: val_loss did not improve from 0.17885
#
# Epoch 00017: val_loss did not improve from 0.17885
#
# Epoch 00018: val_loss improved from 0.17885 to 0.16830, saving model to ./model/18-0.1683.hdf5
#
# Epoch 00019: val_loss improved from 0.16830 to 0.16674, saving model to ./model/19-0.1667.hdf5
#
# Epoch 00020: val_loss improved from 0.16674 to 0.16352, saving model to ./model/20-0.1635.hdf5
#
# Epoch 00021: val_loss improved from 0.16352 to 0.15852, saving model to ./model/21-0.1585.hdf5
#
# Epoch 00022: val_loss improved from 0.15852 to 0.15621, saving model to ./model/22-0.1562.hdf5
#
# Epoch 00023: val_loss did not improve from 0.15621
#
# Epoch 00024: val_loss improved from 0.15621 to 0.15054, saving model to ./model/24-0.1505.hdf5
#
# Epoch 00025: val_loss improved from 0.15054 to 0.14986, saving model to ./model/25-0.1499.hdf5
#
# Epoch 00026: val_loss improved from 0.14986 to 0.14381, saving model to ./model/26-0.1438.hdf5
#
# Epoch 00027: val_loss did not improve from 0.14381
#
# Epoch 00028: val_loss improved from 0.14381 to 0.13630, saving model to ./model/28-0.1363.hdf5
#
# Epoch 00029: val_loss did not improve from 0.13630
#
# Epoch 00030: val_loss improved from 0.13630 to 0.13134, saving model to ./model/30-0.1313.hdf5
#
# Epoch 00031: val_loss did not improve from 0.13134
#
# Epoch 00032: val_loss improved from 0.13134 to 0.13102, saving model to ./model/32-0.1310.hdf5
#
# Epoch 00033: val_loss improved from 0.13102 to 0.12219, saving model to ./model/33-0.1222.hdf5
#
# Epoch 00034: val_loss improved from 0.12219 to 0.12036, saving model to ./model/34-0.1204.hdf5
#
# Epoch 00035: val_loss did not improve from 0.12036
#
# Epoch 00036: val_loss improved from 0.12036 to 0.11785, saving model to ./model/36-0.1178.hdf5
#
# Epoch 00037: val_loss improved from 0.11785 to 0.11052, saving model to ./model/37-0.1105.hdf5
#
# Epoch 00038: val_loss improved from 0.11052 to 0.11000, saving model to ./model/38-0.1100.hdf5
#
# Epoch 00039: val_loss improved from 0.11000 to 0.10550, saving model to ./model/39-0.1055.hdf5
#
# Epoch 00040: val_loss did not improve from 0.10550
#
# Epoch 00041: val_loss improved from 0.10550 to 0.10195, saving model to ./model/41-0.1020.hdf5
#
# Epoch 00042: val_loss did not improve from 0.10195
#
# Epoch 00043: val_loss improved from 0.10195 to 0.10005, saving model to ./model/43-0.1001.hdf5
#
# Epoch 00044: val_loss improved from 0.10005 to 0.09738, saving model to ./model/44-0.0974.hdf5
#
# Epoch 00045: val_loss improved from 0.09738 to 0.09522, saving model to ./model/45-0.0952.hdf5
#
# Epoch 00046: val_loss did not improve from 0.09522
#
# Epoch 00047: val_loss did not improve from 0.09522
#
# Epoch 00048: val_loss improved from 0.09522 to 0.09498, saving model to ./model/48-0.0950.hdf5
#
# Epoch 00049: val_loss improved from 0.09498 to 0.09035, saving model to ./model/49-0.0904.hdf5
#
# Epoch 00050: val_loss did not improve from 0.09035
#
# Epoch 00051: val_loss improved from 0.09035 to 0.08826, saving model to ./model/51-0.0883.hdf5
#
# Epoch 00052: val_loss did not improve from 0.08826
#
# Epoch 00053: val_loss improved from 0.08826 to 0.08561, saving model to ./model/53-0.0856.hdf5
#
# Epoch 00054: val_loss improved from 0.08561 to 0.08518, saving model to ./model/54-0.0852.hdf5
#
# Epoch 00055: val_loss improved from 0.08518 to 0.08356, saving model to ./model/55-0.0836.hdf5
#
# Epoch 00056: val_loss did not improve from 0.08356
#
# Epoch 00057: val_loss did not improve from 0.08356
#
# Epoch 00058: val_loss improved from 0.08356 to 0.08132, saving model to ./model/58-0.0813.hdf5
#
# Epoch 00059: val_loss improved from 0.08132 to 0.07868, saving model to ./model/59-0.0787.hdf5
#
# Epoch 00060: val_loss did not improve from 0.07868
#
# Epoch 00061: val_loss did not improve from 0.07868
#
# Epoch 00062: val_loss improved from 0.07868 to 0.07769, saving model to ./model/62-0.0777.hdf5
#
# Epoch 00063: val_loss improved from 0.07769 to 0.07555, saving model to ./model/63-0.0756.hdf5
#
# Epoch 00064: val_loss did not improve from 0.07555
#
# Epoch 00065: val_loss improved from 0.07555 to 0.07315, saving model to ./model/65-0.0732.hdf5
#
# Epoch 00066: val_loss did not improve from 0.07315
#
# Epoch 00067: val_loss did not improve from 0.07315
#
# Epoch 00068: val_loss improved from 0.07315 to 0.07185, saving model to ./model/68-0.0718.hdf5
#
# Epoch 00069: val_loss did not improve from 0.07185
#
# Epoch 00070: val_loss improved from 0.07185 to 0.07110, saving model to ./model/70-0.0711.hdf5
#
# Epoch 00071: val_loss improved from 0.07110 to 0.07023, saving model to ./model/71-0.0702.hdf5
#
# Epoch 00072: val_loss did not improve from 0.07023
#
# Epoch 00073: val_loss improved from 0.07023 to 0.06945, saving model to ./model/73-0.0694.hdf5
#
# Epoch 00074: val_loss improved from 0.06945 to 0.06784, saving model to ./model/74-0.0678.hdf5
#
# Epoch 00075: val_loss improved from 0.06784 to 0.06760, saving model to ./model/75-0.0676.hdf5
#
# Epoch 00076: val_loss did not improve from 0.06760
#
# Epoch 00077: val_loss did not improve from 0.06760
#
# Epoch 00078: val_loss improved from 0.06760 to 0.06614, saving model to ./model/78-0.0661.hdf5
#
# Epoch 00079: val_loss did not improve from 0.06614
#
# Epoch 00080: val_loss improved from 0.06614 to 0.06614, saving model to ./model/80-0.0661.hdf5
#
# Epoch 00081: val_loss did not improve from 0.06614
#
# Epoch 00082: val_loss did not improve from 0.06614
#
# Epoch 00083: val_loss improved from 0.06614 to 0.06473, saving model to ./model/83-0.0647.hdf5
#
# Epoch 00084: val_loss did not improve from 0.06473
#
# Epoch 00085: val_loss improved from 0.06473 to 0.06414, saving model to ./model/85-0.0641.hdf5
#
# Epoch 00086: val_loss did not improve from 0.06414
#
# Epoch 00087: val_loss did not improve from 0.06414
#
# Epoch 00088: val_loss did not improve from 0.06414
#
# Epoch 00089: val_loss improved from 0.06414 to 0.06260, saving model to ./model/89-0.0626.hdf5
#
# Epoch 00090: val_loss did not improve from 0.06260
#
# Epoch 00091: val_loss did not improve from 0.06260
#
# Epoch 00092: val_loss did not improve from 0.06260
#
# Epoch 00093: val_loss did not improve from 0.06260
#
# Epoch 00094: val_loss did not improve from 0.06260
#
# Epoch 00095: val_loss did not improve from 0.06260
#
# Epoch 00096: val_loss improved from 0.06260 to 0.06142, saving model to ./model/96-0.0614.hdf5
#
# Epoch 00097: val_loss did not improve from 0.06142
#
# Epoch 00098: val_loss did not improve from 0.06142
#
# Epoch 00099: val_loss improved from 0.06142 to 0.06078, saving model to ./model/99-0.0608.hdf5
#
# Epoch 00100: val_loss did not improve from 0.06078
#
# Epoch 00101: val_loss did not improve from 0.06078
#
# Epoch 00102: val_loss did not improve from 0.06078
#
# Epoch 00103: val_loss improved from 0.06078 to 0.06037, saving model to ./model/103-0.0604.hdf5
#
# Epoch 00104: val_loss did not improve from 0.06037
#
# Epoch 00105: val_loss did not improve from 0.06037
#
# Epoch 00106: val_loss did not improve from 0.06037
#
# Epoch 00107: val_loss did not improve from 0.06037
#
# Epoch 00108: val_loss did not improve from 0.06037
#
# Epoch 00109: val_loss did not improve from 0.06037
#
# Epoch 00110: val_loss improved from 0.06037 to 0.05955, saving model to ./model/110-0.0596.hdf5
#
# Epoch 00111: val_loss did not improve from 0.05955
#
# Epoch 00112: val_loss improved from 0.05955 to 0.05797, saving model to ./model/112-0.0580.hdf5
#
# Epoch 00113: val_loss did not improve from 0.05797
#
# Epoch 00114: val_loss did not improve from 0.05797
#
# Epoch 00115: val_loss did not improve from 0.05797
#
# Epoch 00116: val_loss did not improve from 0.05797
#
# Epoch 00117: val_loss did not improve from 0.05797
#
# Epoch 00118: val_loss did not improve from 0.05797
#
# Epoch 00119: val_loss did not improve from 0.05797
#
# Epoch 00120: val_loss did not improve from 0.05797
#
# Epoch 00121: val_loss did not improve from 0.05797
#
# Epoch 00122: val_loss did not improve from 0.05797
#
# Epoch 00123: val_loss improved from 0.05797 to 0.05762, saving model to ./model/123-0.0576.hdf5
#
# Epoch 00124: val_loss did not improve from 0.05762
#
# Epoch 00125: val_loss did not improve from 0.05762
#
# Epoch 00126: val_loss did not improve from 0.05762
#
# Epoch 00127: val_loss improved from 0.05762 to 0.05642, saving model to ./model/127-0.0564.hdf5
#
# Epoch 00128: val_loss did not improve from 0.05642
#
# Epoch 00129: val_loss did not improve from 0.05642
#
# Epoch 00130: val_loss did not improve from 0.05642
#
# Epoch 00131: val_loss did not improve from 0.05642
#
# Epoch 00132: val_loss improved from 0.05642 to 0.05606, saving model to ./model/132-0.0561.hdf5
#
# Epoch 00133: val_loss did not improve from 0.05606
#
# Epoch 00134: val_loss did not improve from 0.05606
#
# Epoch 00135: val_loss did not improve from 0.05606
#
# Epoch 00136: val_loss improved from 0.05606 to 0.05573, saving model to ./model/136-0.0557.hdf5
#
# Epoch 00137: val_loss improved from 0.05573 to 0.05516, saving model to ./model/137-0.0552.hdf5
#
# Epoch 00138: val_loss did not improve from 0.05516
#
# Epoch 00139: val_loss did not improve from 0.05516
#
# Epoch 00140: val_loss did not improve from 0.05516
#
# Epoch 00141: val_loss did not improve from 0.05516
#
# Epoch 00142: val_loss did not improve from 0.05516
#
# Epoch 00143: val_loss improved from 0.05516 to 0.05465, saving model to ./model/143-0.0547.hdf5
#
# Epoch 00144: val_loss did not improve from 0.05465
#
# Epoch 00145: val_loss did not improve from 0.05465
#
# Epoch 00146: val_loss did not improve from 0.05465
#
# Epoch 00147: val_loss did not improve from 0.05465
#
# Epoch 00148: val_loss did not improve from 0.05465
#
# Epoch 00149: val_loss did not improve from 0.05465
#
# Epoch 00150: val_loss did not improve from 0.05465
#
# Epoch 00151: val_loss did not improve from 0.05465
#
# Epoch 00152: val_loss did not improve from 0.05465
#
# Epoch 00153: val_loss did not improve from 0.05465
#
# Epoch 00154: val_loss did not improve from 0.05465
#
# Epoch 00155: val_loss did not improve from 0.05465
#
# Epoch 00156: val_loss did not improve from 0.05465
#
# Epoch 00157: val_loss did not improve from 0.05465
#
# Epoch 00158: val_loss did not improve from 0.05465
#
# Epoch 00159: val_loss did not improve from 0.05465
#
# Epoch 00160: val_loss did not improve from 0.05465
#
# Epoch 00161: val_loss did not improve from 0.05465
#
# Epoch 00162: val_loss improved from 0.05465 to 0.05459, saving model to ./model/162-0.0546.hdf5
#
# Epoch 00163: val_loss did not improve from 0.05459
#
# Epoch 00164: val_loss did not improve from 0.05459
#
# Epoch 00165: val_loss did not improve from 0.05459
#
# Epoch 00166: val_loss improved from 0.05459 to 0.05428, saving model to ./model/166-0.0543.hdf5
#
# Epoch 00167: val_loss did not improve from 0.05428
#
# Epoch 00168: val_loss did not improve from 0.05428
#
# Epoch 00169: val_loss did not improve from 0.05428
#
# Epoch 00170: val_loss did not improve from 0.05428
#
# Epoch 00171: val_loss improved from 0.05428 to 0.05400, saving model to ./model/171-0.0540.hdf5
#
# Epoch 00172: val_loss did not improve from 0.05400
#
# Epoch 00173: val_loss did not improve from 0.05400
#
# Epoch 00174: val_loss did not improve from 0.05400
#
# Epoch 00175: val_loss did not improve from 0.05400
#
# Epoch 00176: val_loss improved from 0.05400 to 0.05388, saving model to ./model/176-0.0539.hdf5
#
# Epoch 00177: val_loss did not improve from 0.05388
#
# Epoch 00178: val_loss did not improve from 0.05388
#
# Epoch 00179: val_loss did not improve from 0.05388
#
# Epoch 00180: val_loss did not improve from 0.05388
#
# Epoch 00181: val_loss did not improve from 0.05388
#
# Epoch 00182: val_loss did not improve from 0.05388
#
# Epoch 00183: val_loss did not improve from 0.05388
#
# Epoch 00184: val_loss did not improve from 0.05388
#
# Epoch 00185: val_loss did not improve from 0.05388
#
# Epoch 00186: val_loss did not improve from 0.05388
#
# Epoch 00187: val_loss did not improve from 0.05388
#
# Epoch 00188: val_loss did not improve from 0.05388
#
# Epoch 00189: val_loss did not improve from 0.05388
#
# Epoch 00190: val_loss did not improve from 0.05388
#
# Epoch 00191: val_loss did not improve from 0.05388
#
# Epoch 00192: val_loss improved from 0.05388 to 0.05345, saving model to ./model/192-0.0534.hdf5
#
# Epoch 00193: val_loss did not improve from 0.05345
#
# Epoch 00194: val_loss did not improve from 0.05345
#
# Epoch 00195: val_loss did not improve from 0.05345
#
# Epoch 00196: val_loss did not improve from 0.05345
#
# Epoch 00197: val_loss did not improve from 0.05345
#
# Epoch 00198: val_loss did not improve from 0.05345
#
# Epoch 00199: val_loss did not improve from 0.05345
#
# Epoch 00200: val_loss did not improve from 0.05345
