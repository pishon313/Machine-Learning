# %% [markdown]
# 생산적대 신경망: 합성하여 가상으로 만들어냄
#
# https://www.thispersondoesnotexist.com/

# %% [markdown]
# 이안 굿펠러 논문 내용 :
# 간 변경 알고리즘 위조 지폐
# - 위조 지폐범은 가짜 지폐를  만들기 위해 노력하고, 경찰은 가짜를 찾기 위해 노력한다
# - 한쪽은 가짜를 만들고, 한쪽은 진짜와 비교하는 경험
# - 가짜를 만들어내는 것은 '생성자(Generator)', 진위를 가려내는 파트를 '판별자(Discriminator)' 라고 부른다

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
if not os.path.exists('./gan_images'):
    os.makedirs('./gan_images')

# %%
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
# 들어오는 값에 0.2를 사용
generator.add(BatchNormalization())
# 가중치 값들을 평균이 0, 가중치 값을 1로 만들어 주는 함수, 가중치가 밖으로 튀지 않도록 잡아준다
generator.add(Reshape((7,7,128))) #1차원으로 나온 128*7*7 개를 3차원으로 재편성
generator.add(UpSampling2D())
#Upsampling2D : Maxpooling2D는 이미지 편접 시 값이 줄어들었던 것을 다시 확장하며 출력값과 입력값이 동일하게 만들어주는 것
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh')) 
# 실제 이미지를 만들기 위해서 출력은 하나가 나오지만

# %%
generator.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 6272)              633472
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 6272)              25088
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 7, 7, 128)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 64)        204864
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# activation_4 (Activation)    (None, 14, 14, 64)        0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 1)         1601
# =================================================================
# Total params: 865,281
# Trainable params: 852,609
# Non-trainable params: 12,672
# _________________________________________________________________

# %%
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding='same'))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding = 'same'))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))

# %%
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False
# discriminator 은 디포릍 값으로 학습을 하지 않는 값을 준다. 
# generator 학습 시, discriminator 은 학습을 하면 안된다. 진위와 판별해야 하기 때문에, 팔변할 떄마다 기준이 바뀌면 곤란하기 때문에

# %%
discriminator.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 14, 14, 64)        1664
# _________________________________________________________________
# activation_5 (Activation)    (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 7, 7, 128)         204928
# _________________________________________________________________
# activation_6 (Activation)    (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 6273
# =================================================================
# Total params: 425,730
# Trainable params: 212,865
# Non-trainable params: 212,865
# _________________________________________________________________

# %%
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
# shape = (100) 100 차원을 넣고, 그것을 generator 가 받는다. 
# generator 을 discrimiator 가 맞고, 그것을 dis_ouput 이 받는다. 
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________

# %%
def gan_train(epoch, batch_size, saving_interval):
    (X_train, _), (_, _) = mnist.load_data()
    X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float')
    X_train = (X_train - 127.5) / 127.5
    
    true = np.ones((batch_size, 1))
    fake = np.zeros((batch_size, 1))
    
    for i in range(epoch):
        idx = np.random.randint(0, X_train.shape[0], batch_size)
        imgs = X_train[idx]
        d_loss_real = discriminator.train_on_batch(imgs, true)
        
        noise = np.random.normal(0, 1, (batch_size, 100))
        gen_imgs = generator.predict(noise)
        d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)
        
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
        g_loss = gan.train_on_batch(noise, true)
        
        print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)
        
        if i % saving_interval == 0:
            noise = np.random.normal(0, 1, (25, 100))
            gen_imgs = generator.predict(noise)
            
            gen_imgs = 0.5 * gen_imgs + 0.5 # 0 ~ 1 rescale
            
            fig, axs = plt.subplots(5, 5)
            count = 0
            for j in range(5):
                for k in range(5):
                    axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                    axs[j, k].axis('off')
                    count += 1
            fig.savefig('gan_images/gan_mnist_%d.png' % i)

# %%
gan_train(4001, 32,200)
# Out:
# epoch:0  d_loss:0.5636  g_loss:0.3678
# epoch:1  d_loss:0.6391  g_loss:0.1626
# epoch:2  d_loss:0.5367  g_loss:0.1593
# epoch:3  d_loss:0.4594  g_loss:0.2331
# epoch:4  d_loss:0.4492  g_loss:0.3380
# epoch:5  d_loss:0.4354  g_loss:0.4263
# epoch:6  d_loss:0.4653  g_loss:0.3852
# epoch:7  d_loss:0.4824  g_loss:0.3168
# epoch:8  d_loss:0.4845  g_loss:0.2664
# epoch:9  d_loss:0.4791  g_loss:0.2341
# epoch:10  d_loss:0.4713  g_loss:0.2464
# epoch:11  d_loss:0.4216  g_loss:0.3525
# epoch:12  d_loss:0.3857  g_loss:0.5346
# epoch:13  d_loss:0.3768  g_loss:0.6679
# epoch:14  d_loss:0.3466  g_loss:0.6928
# epoch:15  d_loss:0.3092  g_loss:0.7736
# epoch:16  d_loss:0.2785  g_loss:0.9364
# epoch:17  d_loss:0.3248  g_loss:1.0006
# epoch:18  d_loss:0.3141  g_loss:1.1286
# epoch:19  d_loss:0.3134  g_loss:1.0567
# epoch:20  d_loss:0.3991  g_loss:0.6777
# epoch:21  d_loss:0.2932  g_loss:0.6269
# epoch:22  d_loss:0.2235  g_loss:0.6740
# epoch:23  d_loss:0.2124  g_loss:0.8490
# epoch:24  d_loss:0.2740  g_loss:0.2748
# epoch:25  d_loss:0.2426  g_loss:0.5262
# epoch:26  d_loss:0.2306  g_loss:1.0057
# epoch:27  d_loss:0.4656  g_loss:0.2920
# epoch:28  d_loss:0.4376  g_loss:0.8782
# epoch:29  d_loss:0.3443  g_loss:1.0293
# epoch:30  d_loss:0.6164  g_loss:0.2853
# epoch:31  d_loss:0.2954  g_loss:1.1625
# epoch:32  d_loss:0.3626  g_loss:0.8052
# epoch:33  d_loss:0.2825  g_loss:0.5875
# epoch:34  d_loss:0.1394  g_loss:1.0350
# epoch:35  d_loss:0.0822  g_loss:1.8183
# epoch:36  d_loss:0.0950  g_loss:1.4644
# epoch:37  d_loss:0.1173  g_loss:1.3077
# epoch:38  d_loss:0.1979  g_loss:1.2128
# epoch:39  d_loss:0.1764  g_loss:2.0472
# epoch:40  d_loss:0.2134  g_loss:1.9405
# epoch:41  d_loss:0.5021  g_loss:1.2473
# epoch:42  d_loss:0.5118  g_loss:1.3060
# epoch:43  d_loss:0.5120  g_loss:1.4148
# epoch:44  d_loss:1.0117  g_loss:1.0074
# epoch:45  d_loss:1.0171  g_loss:0.7253
# epoch:46  d_loss:0.9103  g_loss:1.0282
# epoch:47  d_loss:0.7059  g_loss:1.2796
# epoch:48  d_loss:0.7376  g_loss:1.0323
# epoch:49  d_loss:0.5865  g_loss:1.1698
# epoch:50  d_loss:0.5138  g_loss:1.6748
# epoch:51  d_loss:0.4409  g_loss:1.8881
# epoch:52  d_loss:0.4286  g_loss:1.8103
# epoch:53  d_loss:0.2674  g_loss:1.7457
# epoch:54  d_loss:0.3420  g_loss:2.0983
# epoch:55  d_loss:0.2380  g_loss:2.1760
# epoch:56  d_loss:0.1912  g_loss:2.7516
# epoch:57  d_loss:0.2265  g_loss:2.4346
# epoch:58  d_loss:0.3583  g_loss:1.7758
# epoch:59  d_loss:0.2985  g_loss:1.7463
# epoch:60  d_loss:0.2771  g_loss:1.8259
# epoch:61  d_loss:0.2063  g_loss:2.5128
# epoch:62  d_loss:0.2287  g_loss:1.9990
# epoch:63  d_loss:0.3679  g_loss:1.3523
# epoch:64  d_loss:0.3670  g_loss:0.8643
# epoch:65  d_loss:0.4870  g_loss:0.9415
# epoch:66  d_loss:0.4968  g_loss:0.9721
# epoch:67  d_loss:0.3833  g_loss:0.9567
# epoch:68  d_loss:0.6577  g_loss:0.7418
# epoch:69  d_loss:0.6862  g_loss:0.5574
# epoch:70  d_loss:0.9195  g_loss:0.6153
# epoch:71  d_loss:0.4722  g_loss:1.0982
# epoch:72  d_loss:0.4689  g_loss:1.1277
# epoch:73  d_loss:0.2278  g_loss:1.3534
# epoch:74  d_loss:0.1520  g_loss:1.7176
# epoch:75  d_loss:0.1078  g_loss:2.1818
# epoch:76  d_loss:0.0931  g_loss:2.7262
# epoch:77  d_loss:0.0773  g_loss:2.8066
# epoch:78  d_loss:0.0703  g_loss:3.1187
# epoch:79  d_loss:0.0956  g_loss:3.2515
# epoch:80  d_loss:0.1128  g_loss:3.3270
# epoch:81  d_loss:0.3247  g_loss:3.8991
# epoch:82  d_loss:0.3395  g_loss:4.6720
# epoch:83  d_loss:0.5451  g_loss:4.6090
# epoch:84  d_loss:0.7590  g_loss:3.5394
# epoch:85  d_loss:0.9789  g_loss:3.0996
# epoch:86  d_loss:0.7498  g_loss:3.1002
# epoch:87  d_loss:0.6808  g_loss:3.1732
# epoch:88  d_loss:0.5990  g_loss:3.4011
# epoch:89  d_loss:0.8103  g_loss:2.4058
# epoch:90  d_loss:0.5344  g_loss:1.9356
# epoch:91  d_loss:0.5366  g_loss:2.3273
# epoch:92  d_loss:0.4748  g_loss:1.9774
# epoch:93  d_loss:0.5362  g_loss:1.8869
# epoch:94  d_loss:0.4789  g_loss:1.5785
# epoch:95  d_loss:0.5640  g_loss:1.4504
# epoch:96  d_loss:0.5242  g_loss:1.5295
# epoch:97  d_loss:0.5735  g_loss:1.3337
# epoch:98  d_loss:0.5436  g_loss:1.3488
# epoch:99  d_loss:0.4417  g_loss:1.5038
# epoch:100  d_loss:0.5869  g_loss:1.2256
# epoch:101  d_loss:0.4635  g_loss:1.4853
# epoch:102  d_loss:0.5387  g_loss:1.3617
# epoch:103  d_loss:0.7002  g_loss:0.9620
# epoch:104  d_loss:0.4608  g_loss:1.2167
# epoch:105  d_loss:0.4964  g_loss:0.9735
# epoch:106  d_loss:0.4901  g_loss:0.9997
# epoch:107  d_loss:0.6511  g_loss:1.3285
# epoch:108  d_loss:0.5949  g_loss:1.1352
# epoch:109  d_loss:0.7324  g_loss:0.8196
# epoch:110  d_loss:0.7817  g_loss:0.8852
# epoch:111  d_loss:0.8769  g_loss:1.1191
# epoch:112  d_loss:0.5228  g_loss:1.2802
# epoch:113  d_loss:0.5249  g_loss:1.1124
# epoch:114  d_loss:0.6393  g_loss:1.0865
# epoch:115  d_loss:0.5749  g_loss:1.1980
# epoch:116  d_loss:0.4107  g_loss:1.4190
# epoch:117  d_loss:0.3894  g_loss:1.7847
# epoch:118  d_loss:0.3053  g_loss:2.2075
# epoch:119  d_loss:0.3819  g_loss:1.9847
# epoch:120  d_loss:0.2956  g_loss:1.7010
# epoch:121  d_loss:0.3749  g_loss:1.9132
# epoch:122  d_loss:0.3117  g_loss:1.7707
# epoch:123  d_loss:0.3091  g_loss:2.1525
# epoch:124  d_loss:0.3348  g_loss:2.5560
# epoch:125  d_loss:0.2903  g_loss:2.5919
# epoch:126  d_loss:0.3938  g_loss:2.4525
# epoch:127  d_loss:0.4318  g_loss:2.2200
# epoch:128  d_loss:0.5235  g_loss:2.1579
# epoch:129  d_loss:0.6077  g_loss:2.0514
# epoch:130  d_loss:0.4965  g_loss:2.2863
# epoch:131  d_loss:0.6949  g_loss:2.8436
# epoch:132  d_loss:0.4870  g_loss:2.8673
# epoch:133  d_loss:0.9193  g_loss:2.3171
# epoch:134  d_loss:0.8714  g_loss:1.9044
# epoch:135  d_loss:0.8749  g_loss:1.6180
# epoch:136  d_loss:0.8574  g_loss:1.7753
# epoch:137  d_loss:0.8301  g_loss:1.5256
# epoch:138  d_loss:0.7175  g_loss:2.0264
# epoch:139  d_loss:0.8991  g_loss:1.7234
# epoch:140  d_loss:0.8549  g_loss:1.4485
# epoch:141  d_loss:0.7654  g_loss:1.2581
# epoch:142  d_loss:0.8088  g_loss:1.0805
# epoch:143  d_loss:0.7643  g_loss:1.3102
# epoch:144  d_loss:0.5857  g_loss:1.3014
# epoch:145  d_loss:0.5705  g_loss:1.4436
# epoch:146  d_loss:0.6206  g_loss:1.3995
# epoch:147  d_loss:0.6275  g_loss:1.4016
# epoch:148  d_loss:0.5641  g_loss:1.3345
# epoch:149  d_loss:0.5802  g_loss:1.3159
# epoch:150  d_loss:0.5348  g_loss:1.3734
# epoch:151  d_loss:0.4439  g_loss:1.2586
# epoch:152  d_loss:0.5061  g_loss:1.4377
# epoch:153  d_loss:0.4536  g_loss:1.5606
# epoch:154  d_loss:0.4341  g_loss:1.7504
# epoch:155  d_loss:0.4712  g_loss:1.5953
# epoch:156  d_loss:0.3549  g_loss:1.7099
# epoch:157  d_loss:0.5131  g_loss:1.4549
# epoch:158  d_loss:0.4907  g_loss:1.5266
# epoch:159  d_loss:0.4949  g_loss:1.2485
# epoch:160  d_loss:0.5709  g_loss:1.3152
# epoch:161  d_loss:0.5814  g_loss:1.6773
# epoch:162  d_loss:0.4585  g_loss:1.9497
# epoch:163  d_loss:0.3880  g_loss:1.7257
# epoch:164  d_loss:0.6076  g_loss:1.7750
# epoch:165  d_loss:0.6127  g_loss:1.4126
# epoch:166  d_loss:0.5572  g_loss:1.4531
# epoch:167  d_loss:0.4251  g_loss:1.3594
# epoch:168  d_loss:0.4872  g_loss:1.5603
# epoch:169  d_loss:0.6259  g_loss:1.2567
# epoch:170  d_loss:0.6322  g_loss:1.5068
# epoch:171  d_loss:0.6312  g_loss:1.2878
# epoch:172  d_loss:0.5795  g_loss:1.2431
# epoch:173  d_loss:0.4907  g_loss:1.1809
# epoch:174  d_loss:0.6342  g_loss:1.1598
# epoch:175  d_loss:0.7324  g_loss:1.0775
# epoch:176  d_loss:0.6234  g_loss:1.0662
# epoch:177  d_loss:0.6646  g_loss:1.2264
# epoch:178  d_loss:0.6798  g_loss:1.1562
# epoch:179  d_loss:0.6891  g_loss:1.3274
# epoch:180  d_loss:0.7038  g_loss:0.9842
# epoch:181  d_loss:0.6211  g_loss:1.0191
# epoch:182  d_loss:0.5658  g_loss:1.0310
# epoch:183  d_loss:0.5107  g_loss:1.1706
# epoch:184  d_loss:0.4839  g_loss:1.0372
# epoch:185  d_loss:0.5978  g_loss:0.9189
# epoch:186  d_loss:0.6105  g_loss:1.1480
# epoch:187  d_loss:0.5049  g_loss:1.2099
# epoch:188  d_loss:0.5260  g_loss:1.2198
# epoch:189  d_loss:0.3919  g_loss:1.2145
# epoch:190  d_loss:0.4647  g_loss:1.2298
# epoch:191  d_loss:0.3942  g_loss:1.4508
# epoch:192  d_loss:0.2279  g_loss:1.8419
# epoch:193  d_loss:0.2325  g_loss:2.1882
# epoch:194  d_loss:0.2605  g_loss:2.3229
# epoch:195  d_loss:0.2114  g_loss:2.3759
# epoch:196  d_loss:0.2385  g_loss:2.3053
# epoch:197  d_loss:0.2633  g_loss:2.2255
# epoch:198  d_loss:0.2094  g_loss:2.0625
# epoch:199  d_loss:0.1905  g_loss:2.3454
# epoch:200  d_loss:0.2656  g_loss:2.6325
# epoch:201  d_loss:0.3092  g_loss:2.9693
# epoch:202  d_loss:0.2009  g_loss:3.0910
# epoch:203  d_loss:0.3547  g_loss:3.1763
# epoch:204  d_loss:0.4707  g_loss:2.6445
# epoch:205  d_loss:0.7000  g_loss:1.9077
# epoch:206  d_loss:0.8370  g_loss:1.5703
# epoch:207  d_loss:0.6600  g_loss:1.9762
# epoch:208  d_loss:0.7398  g_loss:2.9526
# epoch:209  d_loss:0.5834  g_loss:3.2849
# epoch:210  d_loss:0.6598  g_loss:2.7730
# epoch:211  d_loss:1.0190  g_loss:1.9430
# epoch:212  d_loss:0.8625  g_loss:1.6710
# epoch:213  d_loss:0.7543  g_loss:1.5500
# epoch:214  d_loss:0.8540  g_loss:1.4682
# epoch:215  d_loss:0.8271  g_loss:1.7404
# epoch:216  d_loss:0.5236  g_loss:2.0413
# epoch:217  d_loss:0.6619  g_loss:2.0346
# epoch:218  d_loss:0.6117  g_loss:1.7926
# epoch:219  d_loss:0.4738  g_loss:1.9991
# epoch:220  d_loss:0.4878  g_loss:1.7320
# epoch:221  d_loss:0.5400  g_loss:1.8961
# epoch:222  d_loss:0.5611  g_loss:1.5949
# epoch:223  d_loss:0.5150  g_loss:1.7788
# epoch:224  d_loss:0.4502  g_loss:1.9573
# epoch:225  d_loss:0.4182  g_loss:1.9838
# epoch:226  d_loss:0.4706  g_loss:2.0477
# epoch:227  d_loss:0.4906  g_loss:2.1828
# epoch:228  d_loss:0.4152  g_loss:1.9899
# epoch:229  d_loss:0.4131  g_loss:1.7695
# epoch:230  d_loss:0.4774  g_loss:1.9931
# epoch:231  d_loss:0.4129  g_loss:1.7075
# epoch:232  d_loss:0.4201  g_loss:1.6418
# epoch:233  d_loss:0.4432  g_loss:1.6699
# epoch:234  d_loss:0.3142  g_loss:1.8770
# epoch:235  d_loss:0.4105  g_loss:2.2829
# epoch:236  d_loss:0.4522  g_loss:1.7969
# epoch:237  d_loss:0.3610  g_loss:1.7511
# epoch:238  d_loss:0.4526  g_loss:1.6408
# epoch:239  d_loss:0.3519  g_loss:1.8575
# epoch:240  d_loss:0.3890  g_loss:1.5573
# epoch:241  d_loss:0.4200  g_loss:1.4923
# epoch:242  d_loss:0.3010  g_loss:1.9036
# epoch:243  d_loss:0.4549  g_loss:1.8237
# epoch:244  d_loss:0.3985  g_loss:1.7169
# epoch:245  d_loss:0.5386  g_loss:1.1647
# epoch:246  d_loss:0.3622  g_loss:1.6691
# epoch:247  d_loss:0.4505  g_loss:1.5843
# epoch:248  d_loss:0.3914  g_loss:1.6393
# epoch:249  d_loss:0.3474  g_loss:1.8173
# epoch:250  d_loss:0.3549  g_loss:1.9242
# epoch:251  d_loss:0.4260  g_loss:1.9246
# epoch:252  d_loss:0.4298  g_loss:1.9025
# epoch:253  d_loss:0.6492  g_loss:1.6730
# epoch:254  d_loss:0.5702  g_loss:1.4106
# epoch:255  d_loss:0.5488  g_loss:1.0923
# epoch:256  d_loss:0.4966  g_loss:1.0938
# epoch:257  d_loss:0.5852  g_loss:1.2861
# epoch:258  d_loss:0.5277  g_loss:1.4548
# epoch:259  d_loss:0.4656  g_loss:1.7623
# epoch:260  d_loss:0.6282  g_loss:1.7138
# epoch:261  d_loss:0.6128  g_loss:1.6091
# epoch:262  d_loss:0.6071  g_loss:1.5491
# epoch:263  d_loss:0.7487  g_loss:1.0512
# epoch:264  d_loss:0.7690  g_loss:1.0892
# epoch:265  d_loss:0.5858  g_loss:1.0706
# epoch:266  d_loss:0.5271  g_loss:1.1862
# epoch:267  d_loss:0.5718  g_loss:1.3638
# epoch:268  d_loss:0.5102  g_loss:1.6256
# epoch:269  d_loss:0.6225  g_loss:1.8847
# epoch:270  d_loss:0.5249  g_loss:1.7335
# epoch:271  d_loss:0.4718  g_loss:1.8262
# epoch:272  d_loss:0.5709  g_loss:1.3755
# epoch:273  d_loss:0.5043  g_loss:1.3807
# epoch:274  d_loss:0.3337  g_loss:1.5408
# epoch:275  d_loss:0.4206  g_loss:1.5827
# epoch:276  d_loss:0.3468  g_loss:2.1863
# epoch:277  d_loss:0.2912  g_loss:2.3933
# epoch:278  d_loss:0.3296  g_loss:2.2633
# epoch:279  d_loss:0.2677  g_loss:2.4163
# epoch:280  d_loss:0.3722  g_loss:2.4205
# epoch:281  d_loss:0.2984  g_loss:2.3277
# epoch:282  d_loss:0.3807  g_loss:2.1198
# epoch:283  d_loss:0.4280  g_loss:2.2559
# epoch:284  d_loss:0.3874  g_loss:2.1954
# epoch:285  d_loss:0.3635  g_loss:2.4078
# epoch:286  d_loss:0.3397  g_loss:2.6540
# epoch:287  d_loss:0.5252  g_loss:2.3860
# epoch:288  d_loss:0.6035  g_loss:1.8553
# epoch:289  d_loss:0.6468  g_loss:2.2117
# epoch:290  d_loss:0.7242  g_loss:2.0172
# epoch:291  d_loss:0.3641  g_loss:2.1576
# epoch:292  d_loss:0.5575  g_loss:2.1427
# epoch:293  d_loss:0.8539  g_loss:1.7970
# epoch:294  d_loss:0.8575  g_loss:1.4082
# epoch:295  d_loss:0.6496  g_loss:1.5314
# epoch:296  d_loss:0.4966  g_loss:1.6294
# epoch:297  d_loss:0.5812  g_loss:1.8588
# epoch:298  d_loss:0.5362  g_loss:1.5747
# epoch:299  d_loss:0.5457  g_loss:1.9078
# epoch:300  d_loss:0.5314  g_loss:1.6526
# epoch:301  d_loss:0.6063  g_loss:1.3555
# epoch:302  d_loss:0.6108  g_loss:1.3442
# epoch:303  d_loss:0.4674  g_loss:1.4248
# epoch:304  d_loss:0.5005  g_loss:1.7503
# epoch:305  d_loss:0.4983  g_loss:1.8591
# epoch:306  d_loss:0.5552  g_loss:1.5714
# epoch:307  d_loss:0.4136  g_loss:1.7041
# epoch:308  d_loss:0.4690  g_loss:1.6658
# epoch:309  d_loss:0.4326  g_loss:1.4104
# epoch:310  d_loss:0.4294  g_loss:1.2732
# epoch:311  d_loss:0.4003  g_loss:1.3962
# epoch:312  d_loss:0.5401  g_loss:1.3297
# epoch:313  d_loss:0.3597  g_loss:1.6981
# epoch:314  d_loss:0.3892  g_loss:1.5626
# epoch:315  d_loss:0.3954  g_loss:1.7662
# epoch:316  d_loss:0.4388  g_loss:1.7138
# epoch:317  d_loss:0.4300  g_loss:1.6696
# epoch:318  d_loss:0.5383  g_loss:1.8584
# epoch:319  d_loss:0.5077  g_loss:1.5882
# epoch:320  d_loss:0.4151  g_loss:1.3602
# epoch:321  d_loss:0.3066  g_loss:1.7656
# epoch:322  d_loss:0.2338  g_loss:1.9240
# epoch:323  d_loss:0.3890  g_loss:1.8124
# epoch:324  d_loss:0.4377  g_loss:1.8249
# epoch:325  d_loss:0.4313  g_loss:1.8879
# epoch:326  d_loss:0.3805  g_loss:1.8979
# epoch:327  d_loss:0.4812  g_loss:2.0623
# epoch:328  d_loss:0.4028  g_loss:2.1811
# epoch:329  d_loss:0.4261  g_loss:1.8857
# epoch:330  d_loss:0.4875  g_loss:1.4426
# epoch:331  d_loss:0.4511  g_loss:1.7290
# epoch:332  d_loss:0.4263  g_loss:1.6175
# epoch:333  d_loss:0.5275  g_loss:1.7295
# epoch:334  d_loss:0.5031  g_loss:2.0746
# epoch:335  d_loss:0.5338  g_loss:1.9846
# epoch:336  d_loss:0.5615  g_loss:1.5108
# epoch:337  d_loss:0.8028  g_loss:1.4917
# epoch:338  d_loss:0.4940  g_loss:1.2214
# epoch:339  d_loss:0.5355  g_loss:1.4380
# epoch:340  d_loss:0.7968  g_loss:1.1221
# epoch:341  d_loss:0.5101  g_loss:1.4791
# epoch:342  d_loss:0.5515  g_loss:1.8187
# epoch:343  d_loss:0.4522  g_loss:1.7316
# epoch:344  d_loss:0.5363  g_loss:1.5631
# epoch:345  d_loss:0.4775  g_loss:1.5017
# epoch:346  d_loss:0.5705  g_loss:1.2979
# epoch:347  d_loss:0.4830  g_loss:1.5019
# epoch:348  d_loss:0.4156  g_loss:1.5050
# epoch:349  d_loss:0.5427  g_loss:1.5890
# epoch:350  d_loss:0.3966  g_loss:1.7796
# epoch:351  d_loss:0.3782  g_loss:1.8626
# epoch:352  d_loss:0.4527  g_loss:1.8488
# epoch:353  d_loss:0.3690  g_loss:2.0341
# epoch:354  d_loss:0.3794  g_loss:1.8358
# epoch:355  d_loss:0.3743  g_loss:1.8926
# epoch:356  d_loss:0.5558  g_loss:1.6743
# epoch:357  d_loss:0.4358  g_loss:2.1082
# epoch:358  d_loss:0.3294  g_loss:2.0425
# epoch:359  d_loss:0.3913  g_loss:2.0073
# epoch:360  d_loss:0.4340  g_loss:1.8937
# epoch:361  d_loss:0.3629  g_loss:1.9123
# epoch:362  d_loss:0.4468  g_loss:1.7845
# epoch:363  d_loss:0.4752  g_loss:1.7262
# epoch:364  d_loss:0.3759  g_loss:2.0166
# epoch:365  d_loss:0.5073  g_loss:1.8435
# epoch:366  d_loss:0.5329  g_loss:1.8069
# epoch:367  d_loss:0.3883  g_loss:1.8407
# epoch:368  d_loss:0.4433  g_loss:1.7428
# epoch:369  d_loss:0.4113  g_loss:1.7962
# epoch:370  d_loss:0.4660  g_loss:1.7971
# epoch:371  d_loss:0.3632  g_loss:1.8638
# epoch:372  d_loss:0.3686  g_loss:2.0002
# epoch:373  d_loss:0.5312  g_loss:1.5701
# epoch:374  d_loss:0.4532  g_loss:1.7281
# epoch:375  d_loss:0.3591  g_loss:1.8840
# epoch:376  d_loss:0.4862  g_loss:1.6040
# epoch:377  d_loss:0.3890  g_loss:1.9509
# epoch:378  d_loss:0.4000  g_loss:1.8265
# epoch:379  d_loss:0.5633  g_loss:1.6911
# epoch:380  d_loss:0.4230  g_loss:1.7288
# epoch:381  d_loss:0.5016  g_loss:1.7803
# epoch:382  d_loss:0.3736  g_loss:1.7337
# epoch:383  d_loss:0.4207  g_loss:1.7617
# epoch:384  d_loss:0.4157  g_loss:1.5511
# epoch:385  d_loss:0.4490  g_loss:1.8681
# epoch:386  d_loss:0.3478  g_loss:2.0476
# epoch:387  d_loss:0.4479  g_loss:1.6887
# epoch:388  d_loss:0.4824  g_loss:1.6178
# epoch:389  d_loss:0.3953  g_loss:1.4443
# epoch:390  d_loss:0.3972  g_loss:1.5228
# epoch:391  d_loss:0.4603  g_loss:1.4214
# epoch:392  d_loss:0.3495  g_loss:1.7917
# epoch:393  d_loss:0.4792  g_loss:1.4268
# epoch:394  d_loss:0.4381  g_loss:1.4978
# epoch:395  d_loss:0.4144  g_loss:1.5617
# epoch:396  d_loss:0.3840  g_loss:1.6168
# epoch:397  d_loss:0.4915  g_loss:1.5445
# epoch:398  d_loss:0.4032  g_loss:1.7122
# epoch:399  d_loss:0.3740  g_loss:1.7974
# epoch:400  d_loss:0.4018  g_loss:1.6655
# epoch:401  d_loss:0.4111  g_loss:2.0155
# epoch:402  d_loss:0.3835  g_loss:2.1406
# epoch:403  d_loss:0.3064  g_loss:1.8295
# epoch:404  d_loss:0.4462  g_loss:1.7928
# epoch:405  d_loss:0.4080  g_loss:1.4919
# epoch:406  d_loss:0.3783  g_loss:1.5727
# epoch:407  d_loss:0.3214  g_loss:1.6820
# epoch:408  d_loss:0.2999  g_loss:2.0258
# epoch:409  d_loss:0.3239  g_loss:2.0817
# epoch:410  d_loss:0.4341  g_loss:1.6945
# epoch:411  d_loss:0.4234  g_loss:1.5910
# epoch:412  d_loss:0.2626  g_loss:1.9334
# epoch:413  d_loss:0.4305  g_loss:1.5239
# epoch:414  d_loss:0.3571  g_loss:2.2400
# epoch:415  d_loss:0.3201  g_loss:2.1982
# epoch:416  d_loss:0.4399  g_loss:2.1925
# epoch:417  d_loss:0.4258  g_loss:2.1128
# epoch:418  d_loss:0.3657  g_loss:1.8205
# epoch:419  d_loss:0.3390  g_loss:1.7626
# epoch:420  d_loss:0.3076  g_loss:1.6222
# epoch:421  d_loss:0.2652  g_loss:1.9619
# epoch:422  d_loss:0.3356  g_loss:2.1108
# epoch:423  d_loss:0.3364  g_loss:2.1929
# epoch:424  d_loss:0.4764  g_loss:2.2791
# epoch:425  d_loss:0.4368  g_loss:1.7043
# epoch:426  d_loss:0.3455  g_loss:1.5547
# epoch:427  d_loss:0.5088  g_loss:1.3761
# epoch:428  d_loss:0.3464  g_loss:2.1254
# epoch:429  d_loss:0.3995  g_loss:2.1962
# epoch:430  d_loss:0.3029  g_loss:2.4566
# epoch:431  d_loss:0.3151  g_loss:2.3682
# epoch:432  d_loss:0.3371  g_loss:2.2443
# epoch:433  d_loss:0.3480  g_loss:1.8168
# epoch:434  d_loss:0.4314  g_loss:1.5950
# epoch:435  d_loss:0.3437  g_loss:1.6727
# epoch:436  d_loss:0.3387  g_loss:1.9673
# epoch:437  d_loss:0.2861  g_loss:2.4694
# epoch:438  d_loss:0.3380  g_loss:2.9270
# epoch:439  d_loss:0.5176  g_loss:2.3741
# epoch:440  d_loss:0.5758  g_loss:1.7040
# epoch:441  d_loss:0.2834  g_loss:2.0754
# epoch:442  d_loss:0.3418  g_loss:2.2478
# epoch:443  d_loss:0.3403  g_loss:2.5009
# epoch:444  d_loss:0.4852  g_loss:2.3686
# epoch:445  d_loss:0.3659  g_loss:2.0946
# epoch:446  d_loss:0.4254  g_loss:2.0602
# epoch:447  d_loss:0.4721  g_loss:1.8658
# epoch:448  d_loss:0.3255  g_loss:2.4436
# epoch:449  d_loss:0.3263  g_loss:1.9563
# epoch:450  d_loss:0.5045  g_loss:1.7262
# epoch:451  d_loss:0.4820  g_loss:2.4282
# epoch:452  d_loss:0.3149  g_loss:2.6654
# epoch:453  d_loss:0.3206  g_loss:2.1621
# epoch:454  d_loss:0.3478  g_loss:2.2652
# epoch:455  d_loss:0.4867  g_loss:1.9841
# epoch:456  d_loss:0.2851  g_loss:2.3069
# epoch:457  d_loss:0.3423  g_loss:2.4058
# epoch:458  d_loss:0.3437  g_loss:2.4968
# epoch:459  d_loss:0.3904  g_loss:2.2397
# epoch:460  d_loss:0.2510  g_loss:2.2969
# epoch:461  d_loss:0.2536  g_loss:2.2177
# epoch:462  d_loss:0.1693  g_loss:2.6987
# epoch:463  d_loss:0.2830  g_loss:2.0528
# epoch:464  d_loss:0.2578  g_loss:2.3355
# epoch:465  d_loss:0.2377  g_loss:2.4825
# epoch:466  d_loss:0.2435  g_loss:2.5486
# epoch:467  d_loss:0.1443  g_loss:3.2325
# epoch:468  d_loss:0.2359  g_loss:2.7007
# epoch:469  d_loss:0.2560  g_loss:2.7208
# epoch:470  d_loss:0.2348  g_loss:2.4407
# epoch:471  d_loss:0.2244  g_loss:2.0460
# epoch:472  d_loss:0.2896  g_loss:2.3513
# epoch:473  d_loss:0.2349  g_loss:2.0003
# epoch:474  d_loss:0.2064  g_loss:2.7825
# epoch:475  d_loss:0.2041  g_loss:2.0188
# epoch:476  d_loss:0.3149  g_loss:2.3417
# epoch:477  d_loss:0.2724  g_loss:2.0419
# epoch:478  d_loss:0.3149  g_loss:2.2765
# epoch:479  d_loss:0.3003  g_loss:1.9644
# epoch:480  d_loss:0.3649  g_loss:2.0412
# epoch:481  d_loss:0.3418  g_loss:2.3674
# epoch:482  d_loss:0.3455  g_loss:2.2957
# epoch:483  d_loss:0.3664  g_loss:2.1115
# epoch:484  d_loss:0.2744  g_loss:1.8081
# epoch:485  d_loss:0.4222  g_loss:1.8766
# epoch:486  d_loss:0.4051  g_loss:2.1840
# epoch:487  d_loss:0.4822  g_loss:1.7648
# epoch:488  d_loss:0.4382  g_loss:1.9356
# epoch:489  d_loss:0.2972  g_loss:1.5790
# epoch:490  d_loss:0.2569  g_loss:2.2226
# epoch:491  d_loss:0.3557  g_loss:2.0180
# epoch:492  d_loss:0.3699  g_loss:1.7198
# epoch:493  d_loss:0.2642  g_loss:2.2931
# epoch:494  d_loss:0.2345  g_loss:2.3396
# epoch:495  d_loss:0.5295  g_loss:2.0255
# epoch:496  d_loss:0.3606  g_loss:1.9069
# epoch:497  d_loss:0.4511  g_loss:1.8032
# epoch:498  d_loss:0.3005  g_loss:3.1154
# epoch:499  d_loss:0.2860  g_loss:3.2285
# epoch:500  d_loss:0.2958  g_loss:2.3354
# epoch:501  d_loss:0.3240  g_loss:1.7292
# epoch:502  d_loss:0.1643  g_loss:2.4104
# epoch:503  d_loss:0.1371  g_loss:2.9503
# epoch:504  d_loss:0.1930  g_loss:3.1161
# epoch:505  d_loss:0.1488  g_loss:2.8459
# epoch:506  d_loss:0.1867  g_loss:2.6138
# epoch:507  d_loss:0.1775  g_loss:2.0951
# epoch:508  d_loss:0.1468  g_loss:2.9760
# epoch:509  d_loss:0.1347  g_loss:2.9726
# epoch:510  d_loss:0.1264  g_loss:3.0628
# epoch:511  d_loss:0.1631  g_loss:3.1159
# epoch:512  d_loss:0.2237  g_loss:2.6859
# epoch:513  d_loss:0.1357  g_loss:2.5267
# epoch:514  d_loss:0.1424  g_loss:2.7561
# epoch:515  d_loss:0.2190  g_loss:2.7364
# epoch:516  d_loss:0.1877  g_loss:2.9944
# epoch:517  d_loss:0.2205  g_loss:2.8498
# epoch:518  d_loss:0.1918  g_loss:2.4238
# epoch:519  d_loss:0.2291  g_loss:2.3771
# epoch:520  d_loss:0.2709  g_loss:2.4782
# epoch:521  d_loss:0.2072  g_loss:2.6219
# epoch:522  d_loss:0.2658  g_loss:2.8428
# epoch:523  d_loss:0.2319  g_loss:2.4539
# epoch:524  d_loss:0.2250  g_loss:2.8215
# epoch:525  d_loss:0.2892  g_loss:2.3501
# epoch:526  d_loss:0.2598  g_loss:2.1494
# epoch:527  d_loss:0.3458  g_loss:2.5574
# epoch:528  d_loss:0.2610  g_loss:2.4644
# epoch:529  d_loss:0.2359  g_loss:2.1952
# epoch:530  d_loss:0.3184  g_loss:2.5338
# epoch:531  d_loss:0.2683  g_loss:2.5907
# epoch:532  d_loss:0.2226  g_loss:2.6854
# epoch:533  d_loss:0.2745  g_loss:2.3213
# epoch:534  d_loss:0.2572  g_loss:2.6689
# epoch:535  d_loss:0.3273  g_loss:3.3907
# epoch:536  d_loss:0.2430  g_loss:2.3121
# epoch:537  d_loss:0.2547  g_loss:2.2725
# epoch:538  d_loss:0.2163  g_loss:2.6246
# epoch:539  d_loss:0.2635  g_loss:2.6247
# epoch:540  d_loss:0.2633  g_loss:3.0705
# epoch:541  d_loss:0.2286  g_loss:2.5673
# epoch:542  d_loss:0.1591  g_loss:3.1286
# epoch:543  d_loss:0.1778  g_loss:3.2811
# epoch:544  d_loss:0.1567  g_loss:2.7925
# epoch:545  d_loss:0.2696  g_loss:2.7278
# epoch:546  d_loss:0.2317  g_loss:2.2832
# epoch:547  d_loss:0.1419  g_loss:2.9453
# epoch:548  d_loss:0.1817  g_loss:3.2929
# epoch:549  d_loss:0.1573  g_loss:3.5532
# epoch:550  d_loss:0.1502  g_loss:3.7674
# epoch:551  d_loss:0.2428  g_loss:2.8970
# epoch:552  d_loss:0.2405  g_loss:2.1866
# epoch:553  d_loss:0.2031  g_loss:2.3802
# epoch:554  d_loss:0.1804  g_loss:2.8752
# epoch:555  d_loss:0.2501  g_loss:2.6711
# epoch:556  d_loss:0.2538  g_loss:3.0025
# epoch:557  d_loss:0.2201  g_loss:3.3056
# epoch:558  d_loss:0.1460  g_loss:2.9780
# epoch:559  d_loss:0.1661  g_loss:2.6228
# epoch:560  d_loss:0.2864  g_loss:2.0705
# epoch:561  d_loss:0.1942  g_loss:2.7935
# epoch:562  d_loss:0.1809  g_loss:3.0073
# epoch:563  d_loss:0.1822  g_loss:3.6266
# epoch:564  d_loss:0.2110  g_loss:3.6871
# epoch:565  d_loss:0.1281  g_loss:3.2707
# epoch:566  d_loss:0.1404  g_loss:3.3767
# epoch:567  d_loss:0.1589  g_loss:2.9092
# epoch:568  d_loss:0.2211  g_loss:2.8933
# epoch:569  d_loss:0.3244  g_loss:2.9616
# epoch:570  d_loss:0.1754  g_loss:3.6314
# epoch:571  d_loss:0.1189  g_loss:4.1927
# epoch:572  d_loss:0.3228  g_loss:2.9224
# epoch:573  d_loss:0.1658  g_loss:2.6983
# epoch:574  d_loss:0.1064  g_loss:2.7351
# epoch:575  d_loss:0.0894  g_loss:4.4830
# epoch:576  d_loss:0.1644  g_loss:3.9837
# epoch:577  d_loss:0.1988  g_loss:3.5590
# epoch:578  d_loss:0.2375  g_loss:2.8455
# epoch:579  d_loss:0.1425  g_loss:3.5108
# epoch:580  d_loss:0.1825  g_loss:3.9024
# epoch:581  d_loss:0.1366  g_loss:3.7682
# epoch:582  d_loss:0.2085  g_loss:3.4971
# epoch:583  d_loss:0.2343  g_loss:2.3252
# epoch:584  d_loss:0.1197  g_loss:3.2345
# epoch:585  d_loss:0.1534  g_loss:3.3775
# epoch:586  d_loss:0.2504  g_loss:2.6157
# epoch:587  d_loss:0.2851  g_loss:2.7116
# epoch:588  d_loss:0.2371  g_loss:3.0526
# epoch:589  d_loss:0.2550  g_loss:2.7073
# epoch:590  d_loss:0.1215  g_loss:2.9131
# epoch:591  d_loss:0.2620  g_loss:2.7912
# epoch:592  d_loss:0.2483  g_loss:2.9309
# epoch:593  d_loss:0.1502  g_loss:2.8871
# epoch:594  d_loss:0.1693  g_loss:3.2589
# epoch:595  d_loss:0.1765  g_loss:3.4253
# epoch:596  d_loss:0.1878  g_loss:3.5852
# epoch:597  d_loss:0.1439  g_loss:3.6111
# epoch:598  d_loss:0.2276  g_loss:3.1058
# epoch:599  d_loss:0.1416  g_loss:2.7663
# epoch:600  d_loss:0.2657  g_loss:2.4282
# epoch:601  d_loss:0.1627  g_loss:4.0411
# epoch:602  d_loss:0.1593  g_loss:4.3327
# epoch:603  d_loss:0.2036  g_loss:3.0755
# epoch:604  d_loss:0.3096  g_loss:2.2704
# epoch:605  d_loss:0.1996  g_loss:2.4992
# epoch:606  d_loss:0.1472  g_loss:3.4075
# epoch:607  d_loss:0.1920  g_loss:3.5768
# epoch:608  d_loss:0.1910  g_loss:3.4874
# epoch:609  d_loss:0.2876  g_loss:2.6790
# epoch:610  d_loss:0.1178  g_loss:3.3404
# epoch:611  d_loss:0.0687  g_loss:3.8785
# epoch:612  d_loss:0.1652  g_loss:3.4408
# epoch:613  d_loss:0.1242  g_loss:3.0336
# epoch:614  d_loss:0.1854  g_loss:2.5385
# epoch:615  d_loss:0.1404  g_loss:2.3420
# epoch:616  d_loss:0.1866  g_loss:3.3110
# epoch:617  d_loss:0.3318  g_loss:3.3634
# epoch:618  d_loss:0.2599  g_loss:2.9536
# epoch:619  d_loss:0.3169  g_loss:2.5307
# epoch:620  d_loss:0.3300  g_loss:2.3353
# epoch:621  d_loss:0.1916  g_loss:2.6899
# epoch:622  d_loss:0.2485  g_loss:2.8628
# epoch:623  d_loss:0.3879  g_loss:2.0135
# epoch:624  d_loss:0.3892  g_loss:1.8822
# epoch:625  d_loss:0.3072  g_loss:2.6629
# epoch:626  d_loss:0.1805  g_loss:3.5352
# epoch:627  d_loss:0.1466  g_loss:3.9925
# epoch:628  d_loss:0.3167  g_loss:4.0076
# epoch:629  d_loss:0.4286  g_loss:2.3162
# epoch:630  d_loss:0.2732  g_loss:1.8318
# epoch:631  d_loss:0.2747  g_loss:2.1693
# epoch:632  d_loss:0.1971  g_loss:3.1943
# epoch:633  d_loss:0.3293  g_loss:3.2048
# epoch:634  d_loss:0.4081  g_loss:3.0384
# epoch:635  d_loss:0.2604  g_loss:3.6840
# epoch:636  d_loss:0.2487  g_loss:3.4345
# epoch:637  d_loss:0.4017  g_loss:2.0676
# epoch:638  d_loss:0.4741  g_loss:2.3560
# epoch:639  d_loss:0.3746  g_loss:2.7527
# epoch:640  d_loss:0.2505  g_loss:2.6313
# epoch:641  d_loss:0.2938  g_loss:2.4742
# epoch:642  d_loss:0.3030  g_loss:2.6348
# epoch:643  d_loss:0.2829  g_loss:3.2580
# epoch:644  d_loss:0.4833  g_loss:2.1050
# epoch:645  d_loss:0.4283  g_loss:2.2018
# epoch:646  d_loss:0.4008  g_loss:2.7070
# epoch:647  d_loss:0.5894  g_loss:2.0965
# epoch:648  d_loss:0.4703  g_loss:2.0147
# epoch:649  d_loss:0.1937  g_loss:3.0263
# epoch:650  d_loss:0.3700  g_loss:2.2898
# epoch:651  d_loss:0.2740  g_loss:1.7323
# epoch:652  d_loss:0.4731  g_loss:1.6383
# epoch:653  d_loss:0.3125  g_loss:2.4088
# epoch:654  d_loss:0.3882  g_loss:2.1699
# epoch:655  d_loss:0.2020  g_loss:2.6099
# epoch:656  d_loss:0.4386  g_loss:2.5285
# epoch:657  d_loss:0.3910  g_loss:2.3972
# epoch:658  d_loss:0.3745  g_loss:2.1525
# epoch:659  d_loss:0.3853  g_loss:2.5286
# epoch:660  d_loss:0.3409  g_loss:3.2178
# epoch:661  d_loss:0.5049  g_loss:2.6454
# epoch:662  d_loss:0.4905  g_loss:2.2144
# epoch:663  d_loss:0.6554  g_loss:1.7157
# epoch:664  d_loss:0.7033  g_loss:1.5412
# epoch:665  d_loss:0.5310  g_loss:1.4714
# epoch:666  d_loss:0.6893  g_loss:1.6263
# epoch:667  d_loss:0.4229  g_loss:1.8641
# epoch:668  d_loss:0.5699  g_loss:1.8467
# epoch:669  d_loss:0.3550  g_loss:2.1342
# epoch:670  d_loss:0.3796  g_loss:2.0745
# epoch:671  d_loss:0.2927  g_loss:2.0475
# epoch:672  d_loss:0.4063  g_loss:2.3999
# epoch:673  d_loss:0.3508  g_loss:2.5690
# epoch:674  d_loss:0.4980  g_loss:2.2101
# epoch:675  d_loss:0.7420  g_loss:1.8606
# epoch:676  d_loss:0.9249  g_loss:1.5165
# epoch:677  d_loss:0.7516  g_loss:1.8077
# epoch:678  d_loss:0.8789  g_loss:1.8431
# epoch:679  d_loss:1.0126  g_loss:1.7009
# epoch:680  d_loss:0.7273  g_loss:1.7588
# epoch:681  d_loss:0.8682  g_loss:1.8359
# epoch:682  d_loss:0.5704  g_loss:2.2725
# epoch:683  d_loss:0.3579  g_loss:2.5285
# epoch:684  d_loss:0.2207  g_loss:2.8608
# epoch:685  d_loss:0.3723  g_loss:3.1871
# epoch:686  d_loss:0.2885  g_loss:2.5578
# epoch:687  d_loss:0.2848  g_loss:2.7482
# epoch:688  d_loss:0.3027  g_loss:2.4909
# epoch:689  d_loss:0.2918  g_loss:2.1714
# epoch:690  d_loss:0.3293  g_loss:2.0530
# epoch:691  d_loss:0.4607  g_loss:1.7046
# epoch:692  d_loss:0.5255  g_loss:1.7946
# epoch:693  d_loss:0.3406  g_loss:2.9541
# epoch:694  d_loss:0.3510  g_loss:2.4616
# epoch:695  d_loss:0.6458  g_loss:1.6527
# epoch:696  d_loss:0.6379  g_loss:2.1134
# epoch:697  d_loss:0.5368  g_loss:2.2949
# epoch:698  d_loss:0.4629  g_loss:2.6641
# epoch:699  d_loss:0.7186  g_loss:3.0278
# epoch:700  d_loss:0.6164  g_loss:2.0456
# epoch:701  d_loss:0.7195  g_loss:1.4619
# epoch:702  d_loss:0.8276  g_loss:1.7383
# epoch:703  d_loss:0.5932  g_loss:1.8331
# epoch:704  d_loss:0.3610  g_loss:2.5998
# epoch:705  d_loss:0.2745  g_loss:3.2523
# epoch:706  d_loss:0.1857  g_loss:3.7947
# epoch:707  d_loss:0.2675  g_loss:3.6427
# epoch:708  d_loss:0.3670  g_loss:2.8092
# epoch:709  d_loss:0.2982  g_loss:2.2812
# epoch:710  d_loss:0.3131  g_loss:1.7962
# epoch:711  d_loss:0.3610  g_loss:2.1444
# epoch:712  d_loss:0.2974  g_loss:2.2312
# epoch:713  d_loss:0.4162  g_loss:2.6964
# epoch:714  d_loss:0.3107  g_loss:2.5940
# epoch:715  d_loss:0.3686  g_loss:2.1683
# epoch:716  d_loss:0.3588  g_loss:2.3673
# epoch:717  d_loss:0.5249  g_loss:1.5320
# epoch:718  d_loss:0.3498  g_loss:2.1161
# epoch:719  d_loss:0.3869  g_loss:2.4127
# epoch:720  d_loss:0.4315  g_loss:1.9279
# epoch:721  d_loss:0.4257  g_loss:2.1129
# epoch:722  d_loss:0.4946  g_loss:1.7088
# epoch:723  d_loss:0.7119  g_loss:1.2186
# epoch:724  d_loss:0.4585  g_loss:1.2662
# epoch:725  d_loss:0.6773  g_loss:1.2086
# epoch:726  d_loss:0.4088  g_loss:1.6950
# epoch:727  d_loss:0.4755  g_loss:1.9981
# epoch:728  d_loss:0.4762  g_loss:2.3440
# epoch:729  d_loss:0.3835  g_loss:1.8969
# epoch:730  d_loss:0.4864  g_loss:1.6845
# epoch:731  d_loss:0.4118  g_loss:1.6951
# epoch:732  d_loss:0.4212  g_loss:2.1233
# epoch:733  d_loss:0.4408  g_loss:1.7304
# epoch:734  d_loss:0.3825  g_loss:2.3774
# epoch:735  d_loss:0.2858  g_loss:1.9376
# epoch:736  d_loss:0.4366  g_loss:1.7781
# epoch:737  d_loss:0.2364  g_loss:2.0971
# epoch:738  d_loss:0.3407  g_loss:2.1947
# epoch:739  d_loss:0.3864  g_loss:2.1797
# epoch:740  d_loss:0.5022  g_loss:1.9295
# epoch:741  d_loss:0.3895  g_loss:1.5833
# epoch:742  d_loss:0.5318  g_loss:1.4891
# epoch:743  d_loss:0.4804  g_loss:1.8052
# epoch:744  d_loss:0.4187  g_loss:1.8832
# epoch:745  d_loss:0.5538  g_loss:1.6090
# epoch:746  d_loss:0.7080  g_loss:1.4377
# epoch:747  d_loss:0.6642  g_loss:1.6689
# epoch:748  d_loss:0.3951  g_loss:1.7448
# epoch:749  d_loss:0.4787  g_loss:1.5343
# epoch:750  d_loss:0.6423  g_loss:1.5026
# epoch:751  d_loss:0.5674  g_loss:1.5836
# epoch:752  d_loss:0.9437  g_loss:1.4760
# epoch:753  d_loss:1.0448  g_loss:1.3064
# epoch:754  d_loss:0.8510  g_loss:1.6980
# epoch:755  d_loss:0.6593  g_loss:1.8101
# epoch:756  d_loss:0.5186  g_loss:1.3876
# epoch:757  d_loss:0.8014  g_loss:1.3524
# epoch:758  d_loss:0.5065  g_loss:1.4488
# epoch:759  d_loss:0.4301  g_loss:1.6328
# epoch:760  d_loss:0.4132  g_loss:2.0003
# epoch:761  d_loss:0.4263  g_loss:2.1775
# epoch:762  d_loss:0.4048  g_loss:2.2389
# epoch:763  d_loss:0.1187  g_loss:2.3259
# epoch:764  d_loss:0.3365  g_loss:1.9045
# epoch:765  d_loss:0.1587  g_loss:2.3571
# epoch:766  d_loss:0.1926  g_loss:2.6623
# epoch:767  d_loss:0.2484  g_loss:2.2708
# epoch:768  d_loss:0.1412  g_loss:2.1637
# epoch:769  d_loss:0.1355  g_loss:2.4510
# epoch:770  d_loss:0.2276  g_loss:2.5966
# epoch:771  d_loss:0.2822  g_loss:2.6835
# epoch:772  d_loss:0.2089  g_loss:2.8052
# epoch:773  d_loss:0.2049  g_loss:2.9238
# epoch:774  d_loss:0.3820  g_loss:2.8354
# epoch:775  d_loss:0.4363  g_loss:2.9327
# epoch:776  d_loss:0.7868  g_loss:1.9756
# epoch:777  d_loss:0.5907  g_loss:2.6229
# epoch:778  d_loss:1.0784  g_loss:1.9568
# epoch:779  d_loss:1.5009  g_loss:1.3010
# epoch:780  d_loss:1.0400  g_loss:1.6243
# epoch:781  d_loss:0.8817  g_loss:1.9886
# epoch:782  d_loss:0.8392  g_loss:1.9250
# epoch:783  d_loss:0.6826  g_loss:1.9021
# epoch:784  d_loss:0.6463  g_loss:1.8835
# epoch:785  d_loss:0.6732  g_loss:1.4318
# epoch:786  d_loss:0.7436  g_loss:1.2175
# epoch:787  d_loss:0.8656  g_loss:1.0658
# epoch:788  d_loss:0.6304  g_loss:1.1632
# epoch:789  d_loss:0.5321  g_loss:1.5815
# epoch:790  d_loss:0.5981  g_loss:1.8969
# epoch:791  d_loss:0.9184  g_loss:1.4953
# epoch:792  d_loss:0.5658  g_loss:1.1934
# epoch:793  d_loss:0.6767  g_loss:1.4373
# epoch:794  d_loss:0.3713  g_loss:1.3113
# epoch:795  d_loss:0.4979  g_loss:1.5784
# epoch:796  d_loss:0.5231  g_loss:1.7784
# epoch:797  d_loss:0.3205  g_loss:2.5808
# epoch:798  d_loss:0.3503  g_loss:2.7265
# epoch:799  d_loss:0.3066  g_loss:2.8064
# epoch:800  d_loss:0.3648  g_loss:2.7212
# epoch:801  d_loss:0.2929  g_loss:2.6100
# epoch:802  d_loss:0.4922  g_loss:1.9517
# epoch:803  d_loss:0.5977  g_loss:1.4014
# epoch:804  d_loss:0.6976  g_loss:1.4606
# epoch:805  d_loss:0.7130  g_loss:1.7281
# epoch:806  d_loss:0.5813  g_loss:1.6814
# epoch:807  d_loss:0.5790  g_loss:2.0408
# epoch:808  d_loss:0.7830  g_loss:1.7698
# epoch:809  d_loss:0.7526  g_loss:1.5321
# epoch:810  d_loss:0.7256  g_loss:1.2700
# epoch:811  d_loss:0.7367  g_loss:1.2215
# epoch:812  d_loss:0.6718  g_loss:1.8104
# epoch:813  d_loss:0.6227  g_loss:2.0462
# epoch:814  d_loss:0.3843  g_loss:2.3346
# epoch:815  d_loss:0.5038  g_loss:2.3291
# epoch:816  d_loss:0.5133  g_loss:2.0997
# epoch:817  d_loss:0.2854  g_loss:2.3492
# epoch:818  d_loss:0.3247  g_loss:2.3756
# epoch:819  d_loss:0.4764  g_loss:2.3140
# epoch:820  d_loss:0.3196  g_loss:1.8197
# epoch:821  d_loss:0.6350  g_loss:1.9548
# epoch:822  d_loss:0.5399  g_loss:1.7466
# epoch:823  d_loss:0.6739  g_loss:1.7323
# epoch:824  d_loss:0.7153  g_loss:1.3317
# epoch:825  d_loss:0.6383  g_loss:1.4451
# epoch:826  d_loss:0.9612  g_loss:1.2517
# epoch:827  d_loss:0.8397  g_loss:0.9782
# epoch:828  d_loss:0.7607  g_loss:0.9411
# epoch:829  d_loss:0.7090  g_loss:0.9997
# epoch:830  d_loss:0.5923  g_loss:1.2997
# epoch:831  d_loss:0.5271  g_loss:1.4966
# epoch:832  d_loss:0.4110  g_loss:1.9592
# epoch:833  d_loss:0.4324  g_loss:2.0862
# epoch:834  d_loss:0.4113  g_loss:2.2043
# epoch:835  d_loss:0.3660  g_loss:2.3854
# epoch:836  d_loss:0.4382  g_loss:2.3418
# epoch:837  d_loss:0.3207  g_loss:2.2861
# epoch:838  d_loss:0.3033  g_loss:1.9296
# epoch:839  d_loss:0.2974  g_loss:1.9628
# epoch:840  d_loss:0.2941  g_loss:2.2261
# epoch:841  d_loss:0.5180  g_loss:1.7559
# epoch:842  d_loss:0.3851  g_loss:2.0398
# epoch:843  d_loss:0.3386  g_loss:2.4031
# epoch:844  d_loss:0.4376  g_loss:2.4276
# epoch:845  d_loss:0.4445  g_loss:2.5073
# epoch:846  d_loss:0.3889  g_loss:2.2082
# epoch:847  d_loss:0.5048  g_loss:1.8185
# epoch:848  d_loss:0.3364  g_loss:1.7378
# epoch:849  d_loss:0.4167  g_loss:1.6820
# epoch:850  d_loss:0.3129  g_loss:1.8999
# epoch:851  d_loss:0.5703  g_loss:1.6748
# epoch:852  d_loss:0.4064  g_loss:2.4892
# epoch:853  d_loss:0.4337  g_loss:2.2125
# epoch:854  d_loss:0.3291  g_loss:2.4185
# epoch:855  d_loss:0.3426  g_loss:2.0567
# epoch:856  d_loss:0.3687  g_loss:2.1820
# epoch:857  d_loss:0.3941  g_loss:2.1201
# epoch:858  d_loss:0.4126  g_loss:1.9124
# epoch:859  d_loss:0.3630  g_loss:1.8659
# epoch:860  d_loss:0.3799  g_loss:1.8254
# epoch:861  d_loss:0.3185  g_loss:2.2190
# epoch:862  d_loss:0.5180  g_loss:1.9280
# epoch:863  d_loss:0.4514  g_loss:1.7851
# epoch:864  d_loss:0.4497  g_loss:2.0227
# epoch:865  d_loss:0.5101  g_loss:1.8275
# epoch:866  d_loss:0.7401  g_loss:1.3820
# epoch:867  d_loss:0.5194  g_loss:1.5008
# epoch:868  d_loss:0.4561  g_loss:1.1779
# epoch:869  d_loss:0.5803  g_loss:1.1730
# epoch:870  d_loss:0.5846  g_loss:1.3645
# epoch:871  d_loss:0.5884  g_loss:1.2422
# epoch:872  d_loss:0.5792  g_loss:1.4202
# epoch:873  d_loss:0.4850  g_loss:1.4392
# epoch:874  d_loss:0.3706  g_loss:1.9321
# epoch:875  d_loss:0.4852  g_loss:1.7818
# epoch:876  d_loss:0.4498  g_loss:1.6128
# epoch:877  d_loss:0.5189  g_loss:1.4001
# epoch:878  d_loss:0.4528  g_loss:1.4535
# epoch:879  d_loss:0.4331  g_loss:1.3371
# epoch:880  d_loss:0.2552  g_loss:1.8972
# epoch:881  d_loss:0.4489  g_loss:1.7898
# epoch:882  d_loss:0.3322  g_loss:2.1472
# epoch:883  d_loss:0.3584  g_loss:2.1325
# epoch:884  d_loss:0.3130  g_loss:2.0897
# epoch:885  d_loss:0.4203  g_loss:2.1430
# epoch:886  d_loss:0.3266  g_loss:2.0976
# epoch:887  d_loss:0.5326  g_loss:1.3479
# epoch:888  d_loss:0.4678  g_loss:2.1033
# epoch:889  d_loss:0.3714  g_loss:2.2718
# epoch:890  d_loss:0.4180  g_loss:2.2284
# epoch:891  d_loss:0.5243  g_loss:1.7761
# epoch:892  d_loss:0.4383  g_loss:1.4643
# epoch:893  d_loss:0.4633  g_loss:1.4783
# epoch:894  d_loss:0.4834  g_loss:1.5911
# epoch:895  d_loss:0.4766  g_loss:1.9103
# epoch:896  d_loss:0.5000  g_loss:1.8307
# epoch:897  d_loss:0.5877  g_loss:1.9872
# epoch:898  d_loss:0.6466  g_loss:1.7810
# epoch:899  d_loss:0.5660  g_loss:1.6075
# epoch:900  d_loss:0.6472  g_loss:1.2485
# epoch:901  d_loss:0.5027  g_loss:1.4946
# epoch:902  d_loss:0.5216  g_loss:1.5102
# epoch:903  d_loss:0.6647  g_loss:1.4015
# epoch:904  d_loss:0.5037  g_loss:1.4783
# epoch:905  d_loss:0.5624  g_loss:1.7194
# epoch:906  d_loss:0.5019  g_loss:1.3259
# epoch:907  d_loss:0.3851  g_loss:1.6081
# epoch:908  d_loss:0.3583  g_loss:1.7208
# epoch:909  d_loss:0.3686  g_loss:2.0336
# epoch:910  d_loss:0.2849  g_loss:2.0365
# epoch:911  d_loss:0.4156  g_loss:1.9053
# epoch:912  d_loss:0.4015  g_loss:1.7583
# epoch:913  d_loss:0.2815  g_loss:1.9820
# epoch:914  d_loss:0.4429  g_loss:1.7745
# epoch:915  d_loss:0.2311  g_loss:1.9635
# epoch:916  d_loss:0.3609  g_loss:1.8069
# epoch:917  d_loss:0.3201  g_loss:2.1846
# epoch:918  d_loss:0.3392  g_loss:1.7168
# epoch:919  d_loss:0.3596  g_loss:1.9237
# epoch:920  d_loss:0.5215  g_loss:1.5301
# epoch:921  d_loss:0.4062  g_loss:1.5986
# epoch:922  d_loss:0.2984  g_loss:2.0017
# epoch:923  d_loss:0.3592  g_loss:2.1804
# epoch:924  d_loss:0.4678  g_loss:2.2369
# epoch:925  d_loss:0.5911  g_loss:1.8917
# epoch:926  d_loss:0.4828  g_loss:1.5565
# epoch:927  d_loss:0.5453  g_loss:1.7540
# epoch:928  d_loss:0.5895  g_loss:1.6608
# epoch:929  d_loss:0.4846  g_loss:2.0152
# epoch:930  d_loss:0.5866  g_loss:1.8412
# epoch:931  d_loss:0.5858  g_loss:1.5362
# epoch:932  d_loss:0.6781  g_loss:1.2424
# epoch:933  d_loss:0.7483  g_loss:1.3448
# epoch:934  d_loss:0.6591  g_loss:1.4881
# epoch:935  d_loss:0.7227  g_loss:1.6194
# epoch:936  d_loss:0.7620  g_loss:1.5950
# epoch:937  d_loss:0.7107  g_loss:1.4296
# epoch:938  d_loss:0.5956  g_loss:1.4528
# epoch:939  d_loss:0.4328  g_loss:1.6037
# epoch:940  d_loss:0.5367  g_loss:1.6880
# epoch:941  d_loss:0.5488  g_loss:1.4468
# epoch:942  d_loss:0.4886  g_loss:1.5099
# epoch:943  d_loss:0.3456  g_loss:1.2771
# epoch:944  d_loss:0.3660  g_loss:1.6146
# epoch:945  d_loss:0.3512  g_loss:1.8312
# epoch:946  d_loss:0.3392  g_loss:2.1155
# epoch:947  d_loss:0.2971  g_loss:2.0136
# epoch:948  d_loss:0.4578  g_loss:1.6712
# epoch:949  d_loss:0.3273  g_loss:2.2806
# epoch:950  d_loss:0.3485  g_loss:1.7761
# epoch:951  d_loss:0.3536  g_loss:1.9795
# epoch:952  d_loss:0.2986  g_loss:2.2694
# epoch:953  d_loss:0.2568  g_loss:2.5711
# epoch:954  d_loss:0.2995  g_loss:2.3504
# epoch:955  d_loss:0.4103  g_loss:2.0063
# epoch:956  d_loss:0.3713  g_loss:1.6962
# epoch:957  d_loss:0.2986  g_loss:2.0032
# epoch:958  d_loss:0.3780  g_loss:2.0436
# epoch:959  d_loss:0.3272  g_loss:2.6748
# epoch:960  d_loss:0.3342  g_loss:2.6249
# epoch:961  d_loss:0.3519  g_loss:2.4508
# epoch:962  d_loss:0.5561  g_loss:1.7461
# epoch:963  d_loss:0.3638  g_loss:1.4223
# epoch:964  d_loss:0.4386  g_loss:1.5644
# epoch:965  d_loss:0.4016  g_loss:2.1884
# epoch:966  d_loss:0.4127  g_loss:1.9423
# epoch:967  d_loss:0.4693  g_loss:2.2425
# epoch:968  d_loss:0.3938  g_loss:2.1391
# epoch:969  d_loss:0.4960  g_loss:2.3809
# epoch:970  d_loss:0.6207  g_loss:1.4658
# epoch:971  d_loss:0.5287  g_loss:1.7378
# epoch:972  d_loss:0.3348  g_loss:2.1738
# epoch:973  d_loss:0.4444  g_loss:2.1350
# epoch:974  d_loss:0.3076  g_loss:2.3276
# epoch:975  d_loss:0.4241  g_loss:2.4130
# epoch:976  d_loss:0.4840  g_loss:2.0116
# epoch:977  d_loss:0.4841  g_loss:1.6533
# epoch:978  d_loss:0.4197  g_loss:2.1290
# epoch:979  d_loss:0.3164  g_loss:2.1778
# epoch:980  d_loss:0.3321  g_loss:2.5020
# epoch:981  d_loss:0.3989  g_loss:2.2033
# epoch:982  d_loss:0.3129  g_loss:2.0123
# epoch:983  d_loss:0.3193  g_loss:2.5618
# epoch:984  d_loss:0.2910  g_loss:2.5401
# epoch:985  d_loss:0.4262  g_loss:2.2779
# epoch:986  d_loss:0.4725  g_loss:2.1921
# epoch:987  d_loss:0.4443  g_loss:2.0542
# epoch:988  d_loss:0.2476  g_loss:2.3789
# epoch:989  d_loss:0.3034  g_loss:2.0320
# epoch:990  d_loss:0.2422  g_loss:2.0952
# epoch:991  d_loss:0.3092  g_loss:2.0842
# epoch:992  d_loss:0.2252  g_loss:2.5233
# epoch:993  d_loss:0.3841  g_loss:2.4502
# epoch:994  d_loss:0.3674  g_loss:2.0849
# epoch:995  d_loss:0.4620  g_loss:1.9557
# epoch:996  d_loss:0.4744  g_loss:2.1240
# epoch:997  d_loss:0.3367  g_loss:2.0746
# epoch:998  d_loss:0.4570  g_loss:2.1792
# epoch:999  d_loss:0.5508  g_loss:2.0202
# epoch:1000  d_loss:0.4766  g_loss:1.9355
# epoch:1001  d_loss:0.6678  g_loss:1.8007
# epoch:1002  d_loss:0.4970  g_loss:1.8141
# epoch:1003  d_loss:0.5510  g_loss:2.1458
# epoch:1004  d_loss:0.7645  g_loss:1.7288
# epoch:1005  d_loss:0.6620  g_loss:2.0034
# epoch:1006  d_loss:0.5474  g_loss:1.5656
# epoch:1007  d_loss:0.4097  g_loss:2.0778
# epoch:1008  d_loss:0.3659  g_loss:1.8457
# epoch:1009  d_loss:0.4227  g_loss:1.6428
# epoch:1010  d_loss:0.4455  g_loss:1.9569
# epoch:1011  d_loss:0.3632  g_loss:2.2664
# epoch:1012  d_loss:0.3615  g_loss:2.2025
# epoch:1013  d_loss:0.3410  g_loss:2.4503
# epoch:1014  d_loss:0.3215  g_loss:2.1576
# epoch:1015  d_loss:0.2904  g_loss:2.3829
# epoch:1016  d_loss:0.3420  g_loss:2.3811
# epoch:1017  d_loss:0.2538  g_loss:2.4528
# epoch:1018  d_loss:0.3454  g_loss:3.1278
# epoch:1019  d_loss:0.2279  g_loss:2.2230
# epoch:1020  d_loss:0.2056  g_loss:2.7276
# epoch:1021  d_loss:0.2456  g_loss:2.5396
# epoch:1022  d_loss:0.3105  g_loss:2.6394
# epoch:1023  d_loss:0.3982  g_loss:2.4310
# epoch:1024  d_loss:0.3321  g_loss:2.3379
# epoch:1025  d_loss:0.3649  g_loss:2.8587
# epoch:1026  d_loss:0.3550  g_loss:2.7194
# epoch:1027  d_loss:0.5226  g_loss:2.0525
# epoch:1028  d_loss:0.4754  g_loss:1.4963
# epoch:1029  d_loss:0.5007  g_loss:1.5565
# epoch:1030  d_loss:0.2904  g_loss:2.5636
# epoch:1031  d_loss:0.2377  g_loss:2.2880
# epoch:1032  d_loss:0.4581  g_loss:2.5510
# epoch:1033  d_loss:0.4694  g_loss:2.0256
# epoch:1034  d_loss:0.4307  g_loss:1.6147
# epoch:1035  d_loss:0.3035  g_loss:2.5356
# epoch:1036  d_loss:0.2948  g_loss:2.7925
# epoch:1037  d_loss:0.5089  g_loss:2.5049
# epoch:1038  d_loss:0.5697  g_loss:1.9848
# epoch:1039  d_loss:0.5477  g_loss:1.7911
# epoch:1040  d_loss:0.6308  g_loss:1.8986
# epoch:1041  d_loss:0.3378  g_loss:2.2752
# epoch:1042  d_loss:0.6338  g_loss:1.8873
# epoch:1043  d_loss:0.5736  g_loss:1.7842
# epoch:1044  d_loss:0.5803  g_loss:1.6114
# epoch:1045  d_loss:0.5096  g_loss:1.5941
# epoch:1046  d_loss:0.4595  g_loss:2.0277
# epoch:1047  d_loss:0.4714  g_loss:2.2970
# epoch:1048  d_loss:0.3660  g_loss:2.7384
# epoch:1049  d_loss:0.5359  g_loss:2.0842
# epoch:1050  d_loss:0.4074  g_loss:2.1563
# epoch:1051  d_loss:0.3814  g_loss:1.9676
# epoch:1052  d_loss:0.2697  g_loss:1.6827
# epoch:1053  d_loss:0.4220  g_loss:1.8404
# epoch:1054  d_loss:0.4389  g_loss:1.9572
# epoch:1055  d_loss:0.2482  g_loss:2.8701
# epoch:1056  d_loss:0.2048  g_loss:3.2012
# epoch:1057  d_loss:0.3894  g_loss:2.4260
# epoch:1058  d_loss:0.2771  g_loss:2.2301
# epoch:1059  d_loss:0.2305  g_loss:2.0928
# epoch:1060  d_loss:0.2750  g_loss:1.9770
# epoch:1061  d_loss:0.3005  g_loss:2.4387
# epoch:1062  d_loss:0.2969  g_loss:2.8874
# epoch:1063  d_loss:0.3437  g_loss:3.1245
# epoch:1064  d_loss:0.3792  g_loss:2.7634
# epoch:1065  d_loss:0.4573  g_loss:2.0362
# epoch:1066  d_loss:0.2834  g_loss:2.1134
# epoch:1067  d_loss:0.3302  g_loss:2.1114
# epoch:1068  d_loss:0.2461  g_loss:2.4200
# epoch:1069  d_loss:0.2847  g_loss:2.4400
# epoch:1070  d_loss:0.2773  g_loss:2.6179
# epoch:1071  d_loss:0.2643  g_loss:2.3256
# epoch:1072  d_loss:0.2263  g_loss:2.1708
# epoch:1073  d_loss:0.3399  g_loss:1.8667
# epoch:1074  d_loss:0.2842  g_loss:1.8994
# epoch:1075  d_loss:0.3011  g_loss:2.2011
# epoch:1076  d_loss:0.3441  g_loss:2.3803
# epoch:1077  d_loss:0.4173  g_loss:2.3775
# epoch:1078  d_loss:0.3112  g_loss:2.1188
# epoch:1079  d_loss:0.3397  g_loss:2.3842
# epoch:1080  d_loss:0.2532  g_loss:2.6008
# epoch:1081  d_loss:0.3558  g_loss:2.2784
# epoch:1082  d_loss:0.3470  g_loss:2.1220
# epoch:1083  d_loss:0.2731  g_loss:1.8423
# epoch:1084  d_loss:0.3248  g_loss:2.2610
# epoch:1085  d_loss:0.4865  g_loss:1.8719
# epoch:1086  d_loss:0.2945  g_loss:2.7755
# epoch:1087  d_loss:0.4952  g_loss:2.2609
# epoch:1088  d_loss:0.4509  g_loss:2.0705
# epoch:1089  d_loss:0.4234  g_loss:1.4062
# epoch:1090  d_loss:0.5534  g_loss:1.5540
# epoch:1091  d_loss:0.5257  g_loss:1.7993
# epoch:1092  d_loss:0.4590  g_loss:1.8225
# epoch:1093  d_loss:0.5314  g_loss:1.6237
# epoch:1094  d_loss:0.3621  g_loss:1.9875
# epoch:1095  d_loss:0.4736  g_loss:1.8548
# epoch:1096  d_loss:0.5031  g_loss:1.4485
# epoch:1097  d_loss:0.4971  g_loss:1.3119
# epoch:1098  d_loss:0.4837  g_loss:1.8179
# epoch:1099  d_loss:0.6042  g_loss:1.4429
# epoch:1100  d_loss:0.4803  g_loss:1.5889
# epoch:1101  d_loss:0.5244  g_loss:1.9371
# epoch:1102  d_loss:0.4030  g_loss:1.9437
# epoch:1103  d_loss:0.2994  g_loss:1.9562
# epoch:1104  d_loss:0.4459  g_loss:1.8861
# epoch:1105  d_loss:0.5197  g_loss:1.8119
# epoch:1106  d_loss:0.3996  g_loss:2.0641
# epoch:1107  d_loss:0.3350  g_loss:2.0393
# epoch:1108  d_loss:0.2965  g_loss:2.0902
# epoch:1109  d_loss:0.3924  g_loss:2.1011
# epoch:1110  d_loss:0.3378  g_loss:2.2878
# epoch:1111  d_loss:0.4657  g_loss:1.8289
# epoch:1112  d_loss:0.4564  g_loss:1.8215
# epoch:1113  d_loss:0.2555  g_loss:1.9590
# epoch:1114  d_loss:0.4047  g_loss:2.0500
# epoch:1115  d_loss:0.3157  g_loss:1.7151
# epoch:1116  d_loss:0.3240  g_loss:2.1439
# epoch:1117  d_loss:0.3346  g_loss:1.9800
# epoch:1118  d_loss:0.2931  g_loss:2.3538
# epoch:1119  d_loss:0.3915  g_loss:2.2303
# epoch:1120  d_loss:0.1758  g_loss:2.3555
# epoch:1121  d_loss:0.3889  g_loss:2.0620
# epoch:1122  d_loss:0.3167  g_loss:2.1872
# epoch:1123  d_loss:0.3681  g_loss:1.7437
# epoch:1124  d_loss:0.3638  g_loss:1.7364
# epoch:1125  d_loss:0.4253  g_loss:2.0855
# epoch:1126  d_loss:0.3746  g_loss:2.0545
# epoch:1127  d_loss:0.2901  g_loss:2.0465
# epoch:1128  d_loss:0.4148  g_loss:2.3476
# epoch:1129  d_loss:0.4837  g_loss:2.4416
# epoch:1130  d_loss:0.3934  g_loss:2.3309
# epoch:1131  d_loss:0.4421  g_loss:1.6939
# epoch:1132  d_loss:0.4477  g_loss:1.6829
# epoch:1133  d_loss:0.6452  g_loss:1.3759
# epoch:1134  d_loss:0.4632  g_loss:1.5036
# epoch:1135  d_loss:0.4134  g_loss:1.8870
# epoch:1136  d_loss:0.3915  g_loss:2.3025
# epoch:1137  d_loss:0.5350  g_loss:1.7025
# epoch:1138  d_loss:0.6082  g_loss:1.3959
# epoch:1139  d_loss:0.5166  g_loss:1.3378
# epoch:1140  d_loss:0.4239  g_loss:1.6169
# epoch:1141  d_loss:0.5731  g_loss:2.0618
# epoch:1142  d_loss:0.4206  g_loss:2.1155
# epoch:1143  d_loss:0.4820  g_loss:2.0014
# epoch:1144  d_loss:0.5953  g_loss:1.3415
# epoch:1145  d_loss:0.5942  g_loss:1.2212
# epoch:1146  d_loss:0.4970  g_loss:1.5048
# epoch:1147  d_loss:0.2892  g_loss:2.1400
# epoch:1148  d_loss:0.3403  g_loss:2.1103
# epoch:1149  d_loss:0.2803  g_loss:2.9076
# epoch:1150  d_loss:0.4938  g_loss:2.2372
# epoch:1151  d_loss:0.3587  g_loss:1.4713
# epoch:1152  d_loss:0.3343  g_loss:1.6080
# epoch:1153  d_loss:0.2489  g_loss:1.6395
# epoch:1154  d_loss:0.3784  g_loss:1.3807
# epoch:1155  d_loss:0.4223  g_loss:1.8440
# epoch:1156  d_loss:0.3791  g_loss:2.2212
# epoch:1157  d_loss:0.5491  g_loss:2.0105
# epoch:1158  d_loss:0.5724  g_loss:1.7224
# epoch:1159  d_loss:0.5504  g_loss:1.5752
# epoch:1160  d_loss:0.4863  g_loss:1.6039
# epoch:1161  d_loss:0.4275  g_loss:2.2503
# epoch:1162  d_loss:0.4776  g_loss:1.8912
# epoch:1163  d_loss:0.4751  g_loss:1.8676
# epoch:1164  d_loss:0.6126  g_loss:1.3665
# epoch:1165  d_loss:0.4342  g_loss:1.8117
# epoch:1166  d_loss:0.4456  g_loss:1.9056
# epoch:1167  d_loss:0.4380  g_loss:1.9727
# epoch:1168  d_loss:0.5618  g_loss:1.8720
# epoch:1169  d_loss:0.5526  g_loss:1.7465
# epoch:1170  d_loss:0.4216  g_loss:1.3216
# epoch:1171  d_loss:0.5872  g_loss:1.4036
# epoch:1172  d_loss:0.4833  g_loss:1.9732
# epoch:1173  d_loss:0.4286  g_loss:2.0082
# epoch:1174  d_loss:0.5966  g_loss:2.1669
# epoch:1175  d_loss:0.4824  g_loss:1.9863
# epoch:1176  d_loss:0.6021  g_loss:1.4795
# epoch:1177  d_loss:0.5304  g_loss:1.5670
# epoch:1178  d_loss:0.3318  g_loss:1.6937
# epoch:1179  d_loss:0.5370  g_loss:1.3474
# epoch:1180  d_loss:0.4831  g_loss:1.4696
# epoch:1181  d_loss:0.5325  g_loss:1.6916
# epoch:1182  d_loss:0.3685  g_loss:1.9563
# epoch:1183  d_loss:0.4861  g_loss:1.9364
# epoch:1184  d_loss:0.4978  g_loss:1.6180
# epoch:1185  d_loss:0.3351  g_loss:1.8148
# epoch:1186  d_loss:0.5269  g_loss:1.4231
# epoch:1187  d_loss:0.4765  g_loss:1.7978
# epoch:1188  d_loss:0.3776  g_loss:2.2242
# epoch:1189  d_loss:0.4556  g_loss:2.0021
# epoch:1190  d_loss:0.3812  g_loss:2.1026
# epoch:1191  d_loss:0.3154  g_loss:2.1602
# epoch:1192  d_loss:0.5720  g_loss:1.9365
# epoch:1193  d_loss:0.3609  g_loss:1.5946
# epoch:1194  d_loss:0.4558  g_loss:1.8520
# epoch:1195  d_loss:0.4493  g_loss:1.8127
# epoch:1196  d_loss:0.4548  g_loss:1.8819
# ...
# epoch:3629  d_loss:0.7290  g_loss:1.2792
# epoch:3630  d_loss:0.5099  g_loss:1.6608
# epoch:3631  d_loss:0.4218  g_loss:1.7198
# epoch:3632  d_loss:0.6395  g_loss:1.4228
# epoch:3633  d_loss:0.3695  g_loss:2.2702
# epoch:3634  d_loss:0.4836  g_loss:1.7110
# epoch:3635  d_loss:0.5660  g_loss:1.6843
# epoch:3636  d_loss:0.7060  g_loss:1.4090
# epoch:3637  d_loss:0.4615  g_loss:1.3287
# epoch:3638  d_loss:0.6457  g_loss:1.3450
# epoch:3639  d_loss:0.5787  g_loss:1.6950
# epoch:3640  d_loss:0.3925  g_loss:1.9975
# epoch:3641  d_loss:0.4534  g_loss:2.2561
# epoch:3642  d_loss:0.5310  g_loss:2.0509
# epoch:3643  d_loss:0.5044  g_loss:1.7150
# epoch:3644  d_loss:0.5770  g_loss:1.1645
# epoch:3645  d_loss:0.4284  g_loss:1.1329
# epoch:3646  d_loss:0.4817  g_loss:1.4086
# epoch:3647  d_loss:0.4606  g_loss:1.7586
# epoch:3648  d_loss:0.4733  g_loss:1.9822
# epoch:3649  d_loss:0.4236  g_loss:1.7699
# epoch:3650  d_loss:0.5408  g_loss:1.6596
# epoch:3651  d_loss:0.4727  g_loss:2.0086
# epoch:3652  d_loss:0.3594  g_loss:1.7724
# epoch:3653  d_loss:0.5798  g_loss:1.6468
# epoch:3654  d_loss:0.3644  g_loss:1.8051
# epoch:3655  d_loss:0.3505  g_loss:1.8113
# epoch:3656  d_loss:0.3511  g_loss:2.0343
# epoch:3657  d_loss:0.3734  g_loss:2.1753
# epoch:3658  d_loss:0.4548  g_loss:2.0840
# epoch:3659  d_loss:0.5152  g_loss:1.9881
# epoch:3660  d_loss:0.5858  g_loss:1.6638
# epoch:3661  d_loss:0.4069  g_loss:2.0265
# epoch:3662  d_loss:0.4346  g_loss:2.2651
# epoch:3663  d_loss:0.4516  g_loss:1.5772
# epoch:3664  d_loss:0.4213  g_loss:1.9421
# epoch:3665  d_loss:0.5243  g_loss:1.7958
# epoch:3666  d_loss:0.6221  g_loss:1.5425
# epoch:3667  d_loss:0.4364  g_loss:1.7411
# epoch:3668  d_loss:0.5694  g_loss:1.5519
# epoch:3669  d_loss:0.4929  g_loss:2.0531
# epoch:3670  d_loss:0.4223  g_loss:2.0606
# epoch:3671  d_loss:0.3535  g_loss:2.1225
# epoch:3672  d_loss:0.5330  g_loss:1.8395
# epoch:3673  d_loss:0.5736  g_loss:1.7756
# epoch:3674  d_loss:0.5681  g_loss:1.4385
# epoch:3675  d_loss:0.4128  g_loss:1.5186
# epoch:3676  d_loss:0.4586  g_loss:1.2986
# epoch:3677  d_loss:0.5010  g_loss:1.5801
# epoch:3678  d_loss:0.4295  g_loss:1.9408
# epoch:3679  d_loss:0.4448  g_loss:1.6682
# epoch:3680  d_loss:0.5132  g_loss:1.6377
# epoch:3681  d_loss:0.3481  g_loss:1.5238
# epoch:3682  d_loss:0.6717  g_loss:1.2345
# epoch:3683  d_loss:0.4555  g_loss:1.4242
# epoch:3684  d_loss:0.3912  g_loss:1.7418
# epoch:3685  d_loss:0.5551  g_loss:1.6566
# epoch:3686  d_loss:0.5183  g_loss:1.8147
# epoch:3687  d_loss:0.3984  g_loss:1.7031
# epoch:3688  d_loss:0.4187  g_loss:1.4779
# epoch:3689  d_loss:0.4408  g_loss:1.7346
# epoch:3690  d_loss:0.5060  g_loss:1.7355
# epoch:3691  d_loss:0.5572  g_loss:1.7712
# epoch:3692  d_loss:0.5702  g_loss:1.5962
# epoch:3693  d_loss:0.4906  g_loss:1.8282
# epoch:3694  d_loss:0.5814  g_loss:1.5578
# epoch:3695  d_loss:0.4390  g_loss:1.9224
# epoch:3696  d_loss:0.4859  g_loss:1.7646
# epoch:3697  d_loss:0.6925  g_loss:1.5709
# epoch:3698  d_loss:0.4762  g_loss:1.7309
# epoch:3699  d_loss:0.4231  g_loss:2.1968
# epoch:3700  d_loss:0.4533  g_loss:1.8605
# epoch:3701  d_loss:0.3803  g_loss:1.9862
# epoch:3702  d_loss:0.4184  g_loss:1.8875
# epoch:3703  d_loss:0.5765  g_loss:1.9300
# epoch:3704  d_loss:0.5306  g_loss:1.3762
# epoch:3705  d_loss:0.4170  g_loss:1.8088
# epoch:3706  d_loss:0.5823  g_loss:1.8841
# epoch:3707  d_loss:0.4655  g_loss:2.0726
# epoch:3708  d_loss:0.4264  g_loss:1.9999
# epoch:3709  d_loss:0.3831  g_loss:1.9533
# epoch:3710  d_loss:0.5076  g_loss:1.8020
# epoch:3711  d_loss:0.5018  g_loss:1.4345
# epoch:3712  d_loss:0.7311  g_loss:1.4407
# epoch:3713  d_loss:0.6091  g_loss:1.4602
# epoch:3714  d_loss:0.4954  g_loss:1.7117
# epoch:3715  d_loss:0.4816  g_loss:2.0492
# epoch:3716  d_loss:0.5198  g_loss:1.5989
# epoch:3717  d_loss:0.4092  g_loss:1.8675
# epoch:3718  d_loss:0.5103  g_loss:1.5637
# epoch:3719  d_loss:0.4454  g_loss:1.5491
# epoch:3720  d_loss:0.4495  g_loss:2.0044
# epoch:3721  d_loss:0.4474  g_loss:1.9069
# epoch:3722  d_loss:0.4714  g_loss:1.6911
# epoch:3723  d_loss:0.3268  g_loss:2.0243
# epoch:3724  d_loss:0.4228  g_loss:1.9224
# epoch:3725  d_loss:0.3281  g_loss:1.7484
# epoch:3726  d_loss:0.2959  g_loss:1.9448
# epoch:3727  d_loss:0.4035  g_loss:1.9947
# epoch:3728  d_loss:0.4172  g_loss:1.7565
# epoch:3729  d_loss:0.3256  g_loss:1.8400
# epoch:3730  d_loss:0.4160  g_loss:1.6160
# epoch:3731  d_loss:0.4267  g_loss:2.0011
# epoch:3732  d_loss:0.2887  g_loss:1.7476
# epoch:3733  d_loss:0.4411  g_loss:1.9973
# epoch:3734  d_loss:0.3486  g_loss:1.9584
# epoch:3735  d_loss:0.5251  g_loss:2.2497
# epoch:3736  d_loss:0.3996  g_loss:2.2558
# epoch:3737  d_loss:0.3692  g_loss:1.8907
# epoch:3738  d_loss:0.3752  g_loss:1.7261
# epoch:3739  d_loss:0.4417  g_loss:1.6220
# epoch:3740  d_loss:0.3770  g_loss:1.5577
# epoch:3741  d_loss:0.3299  g_loss:2.1697
# epoch:3742  d_loss:0.3538  g_loss:2.2439
# epoch:3743  d_loss:0.3894  g_loss:1.9295
# epoch:3744  d_loss:0.4014  g_loss:2.1486
# epoch:3745  d_loss:0.4491  g_loss:1.8301
# epoch:3746  d_loss:0.4201  g_loss:1.9060
# epoch:3747  d_loss:0.5148  g_loss:1.8542
# epoch:3748  d_loss:0.4731  g_loss:2.1144
# epoch:3749  d_loss:0.5028  g_loss:1.7931
# epoch:3750  d_loss:0.5187  g_loss:1.7532
# epoch:3751  d_loss:0.5414  g_loss:1.5933
# epoch:3752  d_loss:0.5419  g_loss:1.9673
# epoch:3753  d_loss:0.5747  g_loss:1.6681
# epoch:3754  d_loss:0.5623  g_loss:1.5800
# epoch:3755  d_loss:0.5512  g_loss:1.5910
# epoch:3756  d_loss:0.5641  g_loss:1.6604
# epoch:3757  d_loss:0.5537  g_loss:1.8195
# epoch:3758  d_loss:0.5637  g_loss:1.7734
# epoch:3759  d_loss:0.5917  g_loss:1.2921
# epoch:3760  d_loss:0.6616  g_loss:1.4586
# epoch:3761  d_loss:0.3933  g_loss:1.6521
# epoch:3762  d_loss:0.6677  g_loss:1.6387
# epoch:3763  d_loss:0.4944  g_loss:1.8426
# epoch:3764  d_loss:0.4950  g_loss:1.8202
# epoch:3765  d_loss:0.4832  g_loss:1.7622
# epoch:3766  d_loss:0.5837  g_loss:1.5574
# epoch:3767  d_loss:0.4635  g_loss:1.5646
# epoch:3768  d_loss:0.5456  g_loss:1.3156
# epoch:3769  d_loss:0.3594  g_loss:1.5688
# epoch:3770  d_loss:0.4927  g_loss:1.9109
# epoch:3771  d_loss:0.4437  g_loss:2.0965
# epoch:3772  d_loss:0.4037  g_loss:2.3282
# epoch:3773  d_loss:0.4165  g_loss:2.1422
# epoch:3774  d_loss:0.5258  g_loss:2.0069
# epoch:3775  d_loss:0.4666  g_loss:2.2468
# epoch:3776  d_loss:0.2800  g_loss:2.7650
# epoch:3777  d_loss:0.3150  g_loss:2.1320
# epoch:3778  d_loss:0.4778  g_loss:1.6071
# epoch:3779  d_loss:0.2839  g_loss:2.3470
# epoch:3780  d_loss:0.3880  g_loss:2.2664
# epoch:3781  d_loss:0.4226  g_loss:2.5506
# epoch:3782  d_loss:0.3142  g_loss:2.3700
# epoch:3783  d_loss:0.4500  g_loss:2.0821
# epoch:3784  d_loss:0.4509  g_loss:1.8568
# epoch:3785  d_loss:0.3273  g_loss:1.6782
# epoch:3786  d_loss:0.3483  g_loss:1.5433
# epoch:3787  d_loss:0.3652  g_loss:1.5153
# epoch:3788  d_loss:0.3373  g_loss:1.4595
# epoch:3789  d_loss:0.4404  g_loss:2.0615
# epoch:3790  d_loss:0.4688  g_loss:1.8085
# epoch:3791  d_loss:0.4349  g_loss:1.8802
# epoch:3792  d_loss:0.4058  g_loss:2.0206
# epoch:3793  d_loss:0.4744  g_loss:1.4548
# epoch:3794  d_loss:0.3387  g_loss:1.6535
# epoch:3795  d_loss:0.6120  g_loss:1.8934
# epoch:3796  d_loss:0.4436  g_loss:2.1967
# epoch:3797  d_loss:0.4770  g_loss:1.9939
# epoch:3798  d_loss:0.5870  g_loss:1.8443
# epoch:3799  d_loss:0.5298  g_loss:1.4396
# epoch:3800  d_loss:0.5546  g_loss:1.3138
# /Users/jeongsarah/opt/anaconda3/envs/python-env/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# epoch:3801  d_loss:0.4500  g_loss:1.3062
# epoch:3802  d_loss:0.4628  g_loss:1.4539
# epoch:3803  d_loss:0.5351  g_loss:1.8429
# epoch:3804  d_loss:0.5198  g_loss:1.8678
# epoch:3805  d_loss:0.6099  g_loss:2.0097
# epoch:3806  d_loss:0.7098  g_loss:1.4865
# epoch:3807  d_loss:0.4756  g_loss:1.4446
# epoch:3808  d_loss:0.6402  g_loss:1.6123
# epoch:3809  d_loss:0.5563  g_loss:1.3279
# epoch:3810  d_loss:0.4963  g_loss:1.8450
# epoch:3811  d_loss:0.5558  g_loss:1.7994
# epoch:3812  d_loss:0.4349  g_loss:2.0034
# epoch:3813  d_loss:0.4623  g_loss:1.8801
# epoch:3814  d_loss:0.5693  g_loss:1.9066
# epoch:3815  d_loss:0.4397  g_loss:1.6523
# epoch:3816  d_loss:0.4710  g_loss:1.4391
# epoch:3817  d_loss:0.4710  g_loss:1.3894
# epoch:3818  d_loss:0.5756  g_loss:1.1793
# epoch:3819  d_loss:0.5018  g_loss:1.5688
# epoch:3820  d_loss:0.4203  g_loss:2.0671
# epoch:3821  d_loss:0.5185  g_loss:1.7692
# epoch:3822  d_loss:0.5000  g_loss:1.6455
# epoch:3823  d_loss:0.4512  g_loss:1.8190
# epoch:3824  d_loss:0.4685  g_loss:1.5160
# epoch:3825  d_loss:0.4058  g_loss:1.3593
# epoch:3826  d_loss:0.4297  g_loss:1.6401
# epoch:3827  d_loss:0.5098  g_loss:1.7797
# epoch:3828  d_loss:0.4726  g_loss:2.2422
# epoch:3829  d_loss:0.4268  g_loss:2.0567
# epoch:3830  d_loss:0.4832  g_loss:2.1276
# epoch:3831  d_loss:0.4121  g_loss:1.7855
# epoch:3832  d_loss:0.5484  g_loss:1.7875
# epoch:3833  d_loss:0.3361  g_loss:1.6213
# epoch:3834  d_loss:0.5049  g_loss:1.2340
# epoch:3835  d_loss:0.4043  g_loss:1.8904
# epoch:3836  d_loss:0.4356  g_loss:2.3544
# epoch:3837  d_loss:0.6864  g_loss:2.1858
# epoch:3838  d_loss:0.3527  g_loss:2.2317
# epoch:3839  d_loss:0.4763  g_loss:2.1963
# epoch:3840  d_loss:0.5408  g_loss:1.7436
# epoch:3841  d_loss:0.5484  g_loss:1.6461
# epoch:3842  d_loss:0.5917  g_loss:1.3406
# epoch:3843  d_loss:0.4445  g_loss:1.8641
# epoch:3844  d_loss:0.5757  g_loss:1.4621
# epoch:3845  d_loss:0.5264  g_loss:2.0497
# epoch:3846  d_loss:0.5389  g_loss:1.7700
# epoch:3847  d_loss:0.3666  g_loss:2.1444
# epoch:3848  d_loss:0.4992  g_loss:2.1148
# epoch:3849  d_loss:0.3662  g_loss:2.1115
# epoch:3850  d_loss:0.5927  g_loss:1.6130
# epoch:3851  d_loss:0.5095  g_loss:1.6079
# epoch:3852  d_loss:0.4136  g_loss:1.7010
# epoch:3853  d_loss:0.5614  g_loss:1.7330
# epoch:3854  d_loss:0.4429  g_loss:1.8520
# epoch:3855  d_loss:0.4764  g_loss:1.9015
# epoch:3856  d_loss:0.4051  g_loss:2.1395
# epoch:3857  d_loss:0.5991  g_loss:1.5949
# epoch:3858  d_loss:0.7068  g_loss:1.3366
# epoch:3859  d_loss:0.5869  g_loss:1.6454
# epoch:3860  d_loss:0.3922  g_loss:1.7463
# epoch:3861  d_loss:0.3695  g_loss:1.6959
# epoch:3862  d_loss:0.4285  g_loss:1.8199
# epoch:3863  d_loss:0.4236  g_loss:2.2459
# epoch:3864  d_loss:0.4177  g_loss:2.3088
# epoch:3865  d_loss:0.4501  g_loss:1.9307
# epoch:3866  d_loss:0.6782  g_loss:1.5817
# epoch:3867  d_loss:0.4230  g_loss:1.3806
# epoch:3868  d_loss:0.5756  g_loss:1.5830
# epoch:3869  d_loss:0.4478  g_loss:1.4719
# epoch:3870  d_loss:0.4827  g_loss:1.7289
# epoch:3871  d_loss:0.5755  g_loss:1.7911
# epoch:3872  d_loss:0.4514  g_loss:1.4329
# epoch:3873  d_loss:0.6750  g_loss:1.2946
# epoch:3874  d_loss:0.3227  g_loss:1.4907
# epoch:3875  d_loss:0.6067  g_loss:1.1309
# epoch:3876  d_loss:0.4386  g_loss:1.6977
# epoch:3877  d_loss:0.4036  g_loss:1.9370
# epoch:3878  d_loss:0.6356  g_loss:1.9000
# epoch:3879  d_loss:0.5298  g_loss:1.6798
# epoch:3880  d_loss:0.5006  g_loss:1.4945
# epoch:3881  d_loss:0.5091  g_loss:1.5658
# epoch:3882  d_loss:0.4735  g_loss:1.5789
# epoch:3883  d_loss:0.4342  g_loss:1.6477
# epoch:3884  d_loss:0.4048  g_loss:2.2370
# epoch:3885  d_loss:0.5309  g_loss:1.9831
# epoch:3886  d_loss:0.5105  g_loss:1.6828
# epoch:3887  d_loss:0.4563  g_loss:1.9416
# epoch:3888  d_loss:0.4004  g_loss:1.5193
# epoch:3889  d_loss:0.4716  g_loss:1.6236
# epoch:3890  d_loss:0.4788  g_loss:1.5418
# epoch:3891  d_loss:0.5239  g_loss:1.5596
# epoch:3892  d_loss:0.4859  g_loss:1.8650
# epoch:3893  d_loss:0.3413  g_loss:1.6956
# epoch:3894  d_loss:0.5346  g_loss:1.7508
# epoch:3895  d_loss:0.5871  g_loss:1.5172
# epoch:3896  d_loss:0.5625  g_loss:1.5573
# epoch:3897  d_loss:0.5733  g_loss:1.7326
# epoch:3898  d_loss:0.4943  g_loss:1.9235
# epoch:3899  d_loss:0.5734  g_loss:2.1991
# epoch:3900  d_loss:0.6460  g_loss:1.8095
# epoch:3901  d_loss:0.6167  g_loss:1.5401
# epoch:3902  d_loss:0.6546  g_loss:1.5648
# epoch:3903  d_loss:0.6122  g_loss:1.6426
# epoch:3904  d_loss:0.5501  g_loss:1.6467
# epoch:3905  d_loss:0.4075  g_loss:1.6073
# epoch:3906  d_loss:0.5873  g_loss:1.7138
# epoch:3907  d_loss:0.4672  g_loss:1.4956
# epoch:3908  d_loss:0.6064  g_loss:1.1420
# epoch:3909  d_loss:0.3952  g_loss:1.7619
# epoch:3910  d_loss:0.3409  g_loss:2.0776
# epoch:3911  d_loss:0.5204  g_loss:1.7106
# epoch:3912  d_loss:0.5007  g_loss:1.7909
# epoch:3913  d_loss:0.4619  g_loss:1.3194
# epoch:3914  d_loss:0.4103  g_loss:1.2980
# epoch:3915  d_loss:0.5129  g_loss:1.3632
# epoch:3916  d_loss:0.3951  g_loss:1.9235
# epoch:3917  d_loss:0.4109  g_loss:2.0733
# epoch:3918  d_loss:0.4815  g_loss:1.7528
# epoch:3919  d_loss:0.5580  g_loss:1.5352
# epoch:3920  d_loss:0.6397  g_loss:1.5164
# epoch:3921  d_loss:0.5521  g_loss:1.4894
# epoch:3922  d_loss:0.5181  g_loss:1.5928
# epoch:3923  d_loss:0.4266  g_loss:1.8250
# epoch:3924  d_loss:0.3969  g_loss:1.7920
# epoch:3925  d_loss:0.4465  g_loss:1.8692
# epoch:3926  d_loss:0.3880  g_loss:1.5960
# epoch:3927  d_loss:0.5314  g_loss:1.2282
# epoch:3928  d_loss:0.5836  g_loss:1.6623
# epoch:3929  d_loss:0.4461  g_loss:1.6595
# epoch:3930  d_loss:0.4352  g_loss:1.6119
# epoch:3931  d_loss:0.4490  g_loss:1.9227
# epoch:3932  d_loss:0.4953  g_loss:1.9666
# epoch:3933  d_loss:0.5515  g_loss:1.7060
# epoch:3934  d_loss:0.5204  g_loss:1.8142
# epoch:3935  d_loss:0.4563  g_loss:1.4469
# epoch:3936  d_loss:0.4687  g_loss:1.5961
# epoch:3937  d_loss:0.5395  g_loss:1.5685
# epoch:3938  d_loss:0.4343  g_loss:1.5086
# epoch:3939  d_loss:0.4294  g_loss:1.9854
# epoch:3940  d_loss:0.5460  g_loss:1.8536
# epoch:3941  d_loss:0.5818  g_loss:1.4374
# epoch:3942  d_loss:0.5261  g_loss:1.1151
# epoch:3943  d_loss:0.4795  g_loss:1.8413
# epoch:3944  d_loss:0.4813  g_loss:1.8331
# epoch:3945  d_loss:0.4519  g_loss:1.6231
# epoch:3946  d_loss:0.5251  g_loss:1.8483
# epoch:3947  d_loss:0.5649  g_loss:1.5659
# epoch:3948  d_loss:0.5636  g_loss:1.2657
# epoch:3949  d_loss:0.5601  g_loss:1.4338
# epoch:3950  d_loss:0.5354  g_loss:1.3811
# epoch:3951  d_loss:0.5203  g_loss:1.7293
# epoch:3952  d_loss:0.4891  g_loss:1.7566
# epoch:3953  d_loss:0.5240  g_loss:1.8913
# epoch:3954  d_loss:0.4995  g_loss:1.5259
# epoch:3955  d_loss:0.7164  g_loss:1.2489
# epoch:3956  d_loss:0.4171  g_loss:1.4114
# epoch:3957  d_loss:0.4799  g_loss:1.2583
# epoch:3958  d_loss:0.3720  g_loss:1.7182
# epoch:3959  d_loss:0.4707  g_loss:1.7833
# epoch:3960  d_loss:0.3813  g_loss:1.9207
# epoch:3961  d_loss:0.3816  g_loss:1.8455
# epoch:3962  d_loss:0.3763  g_loss:1.8026
# epoch:3963  d_loss:0.4298  g_loss:1.7080
# epoch:3964  d_loss:0.4301  g_loss:1.7021
# epoch:3965  d_loss:0.4399  g_loss:1.2732
# epoch:3966  d_loss:0.4103  g_loss:2.0290
# epoch:3967  d_loss:0.3523  g_loss:1.8152
# epoch:3968  d_loss:0.4783  g_loss:2.1672
# epoch:3969  d_loss:0.4454  g_loss:1.8785
# epoch:3970  d_loss:0.4231  g_loss:1.9778
# epoch:3971  d_loss:0.5489  g_loss:1.3874
# epoch:3972  d_loss:0.3924  g_loss:1.5581
# epoch:3973  d_loss:0.5447  g_loss:1.4891
# epoch:3974  d_loss:0.5301  g_loss:1.4153
# epoch:3975  d_loss:0.5307  g_loss:1.5424
# epoch:3976  d_loss:0.5579  g_loss:1.8121
# epoch:3977  d_loss:0.5256  g_loss:1.9160
# epoch:3978  d_loss:0.5695  g_loss:1.7385
# epoch:3979  d_loss:0.3882  g_loss:1.7395
# epoch:3980  d_loss:0.4381  g_loss:1.7889
# epoch:3981  d_loss:0.4866  g_loss:1.7189
# epoch:3982  d_loss:0.5761  g_loss:1.5029
# epoch:3983  d_loss:0.6103  g_loss:1.2661
# epoch:3984  d_loss:0.5045  g_loss:1.3835
# epoch:3985  d_loss:0.3642  g_loss:2.2049
# epoch:3986  d_loss:0.4759  g_loss:1.8432
# epoch:3987  d_loss:0.4574  g_loss:2.0731
# epoch:3988  d_loss:0.4217  g_loss:1.6113
# epoch:3989  d_loss:0.5231  g_loss:1.6950
# epoch:3990  d_loss:0.4623  g_loss:1.3261
# epoch:3991  d_loss:0.2977  g_loss:1.5662
# epoch:3992  d_loss:0.4053  g_loss:1.5109
# epoch:3993  d_loss:0.4275  g_loss:1.7948
# epoch:3994  d_loss:0.4785  g_loss:1.9984
# epoch:3995  d_loss:0.4969  g_loss:1.7372
# epoch:3996  d_loss:0.3756  g_loss:2.1032
# epoch:3997  d_loss:0.4603  g_loss:1.7711
# epoch:3998  d_loss:0.4963  g_loss:2.0221
# epoch:3999  d_loss:0.4940  g_loss:1.7090
# epoch:4000  d_loss:0.5165  g_loss:1.8108
# /Users/jeongsarah/opt/anaconda3/envs/python-env/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
# reaky_ReLU 설명
import numpy as np

def leaky_relu_function(x):
    return np.where(x <= 0, 0.01*x, x)

x = np.linspace(-5,5)
y = leaky_relu_function(x)

plt(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4c3b1aa8545b> in <module>
#       8 y = leaky_relu_function(x)
#       9
# ---> 10 plt(x,y)
#      11 plt.show()
#
# NameError: name 'plt' is not defined
