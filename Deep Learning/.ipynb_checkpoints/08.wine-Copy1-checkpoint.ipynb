# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
seed = 0
np.random.seed(seed)
tf.random.set_seed(3)

# %%
# df = df_pre.sample(frac=1)
df_pre = pd.read_csv('data/wine.csv')
df = df_pre.sample(frac=1)  # 전체 데이터에서 샘플을 가져온다. 1= 100%, 0.7 = 70%

# %%
print(df.head())
# Out:
#       7.4   0.7     0   1.9  0.076    11     34   0.9978  3.51  0.56   9.4  5  \
# 5315  6.3  0.18  0.24   3.4  0.053  20.0  119.0  0.99373  3.11  0.52   9.2  6
# 2423  7.0  0.21  0.37   7.2  0.042  36.0  167.0  0.99580  3.26  0.56   9.8  6
# 3517  7.3  0.22  0.50  13.7  0.049  56.0  189.0  0.99940  3.24  0.66   9.0  6
# 1622  6.6  0.27  0.41   1.3  0.052  16.0  142.0  0.99510  3.42  0.47  10.0  6
# 4060  8.3  0.25  0.33   2.5  0.053  12.0   72.0  0.99404  2.89  0.48   9.5  5
#
#       1
# 5315  0
# 2423  0
# 3517  0
# 1622  0
# 4060  0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6496 entries, 5315 to 2732
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   7.4     6496 non-null   float64
#  1   0.7     6496 non-null   float64
#  2   0       6496 non-null   float64
#  3   1.9     6496 non-null   float64
#  4   0.076   6496 non-null   float64
#  5   11      6496 non-null   float64
#  6   34      6496 non-null   float64
#  7   0.9978  6496 non-null   float64
#  8   3.51    6496 non-null   float64
#  9   0.56    6496 non-null   float64
#  10  9.4     6496 non-null   float64
#  11  5       6496 non-null   int64
#  12  1       6496 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 710.5 KB
# None

# %%
# 1: red wine, 0: white wine
# 1과 0을 구분하는 회귀, 바이너리 연산

# %%
dataset = df.values
print(dataset.dtype)
# 전체가 float 이므로 형변환 불필요
# Out:
# float64

# %%
X = dataset[:, :12]
Y = dataset[:, 12]

# %%
model = Sequential()
model.add(Dense(30, input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 30)                390
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                372
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 875
# Trainable params: 875
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 손실 함수 및 optimize 연걸
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
import os

MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR) :  # 같은 파일명이 존재하는지 확인
    os.mkdir(MODEL_DIR)   # 모델 생성
    

modelpath = './model/{epoch:02d}-{val_loss:.4f}.hdf5'
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True) # 체크포인트 생성, 무엇을 체크할 것인지 지정(mointor)

# monitor=val_loss : 무엇을 체크할 것인지 지정. val_loss 를 관찰하라는 뜻
# verbose=1 : 중간 과정을 계속 출력하라
# save_best_only=True : 모델이 향상될 때만 저장하라

# %%
model.fit(X, Y, validation_split=0.2, epochs=200, batch_size=200, verbose=0, callbacks=[checkpointer])

# validation_split=0.2 : 20% 를 뗴어놓고, 80%만 훈련시킨 후, 나머지 20% 를 validate을 해주고, 그때마다 그 값을 나타내 보여달라
# verbose=0 : 출력 값을 보이지 마라
# print("Accuracy:  %.4f" % (model.evaluate(X, Y)))
# Out:
# Epoch 00001: saving model to ./model/01-0.3737.hdf5
#
# Epoch 00002: saving model to ./model/02-0.2821.hdf5
#
# Epoch 00003: saving model to ./model/03-0.2381.hdf5
#
# Epoch 00004: saving model to ./model/04-0.2293.hdf5
#
# Epoch 00005: saving model to ./model/05-0.2231.hdf5
#
# Epoch 00006: saving model to ./model/06-0.2199.hdf5
#
# Epoch 00007: saving model to ./model/07-0.2104.hdf5
#
# Epoch 00008: saving model to ./model/08-0.2070.hdf5
#
# Epoch 00009: saving model to ./model/09-0.2015.hdf5
#
# Epoch 00010: saving model to ./model/10-0.1957.hdf5
#
# Epoch 00011: saving model to ./model/11-0.1897.hdf5
#
# Epoch 00012: saving model to ./model/12-0.1894.hdf5
#
# Epoch 00013: saving model to ./model/13-0.1869.hdf5
#
# Epoch 00014: saving model to ./model/14-0.1789.hdf5
#
# Epoch 00015: saving model to ./model/15-0.1796.hdf5
#
# Epoch 00016: saving model to ./model/16-0.1801.hdf5
#
# Epoch 00017: saving model to ./model/17-0.1831.hdf5
#
# Epoch 00018: saving model to ./model/18-0.1683.hdf5
#
# Epoch 00019: saving model to ./model/19-0.1667.hdf5
#
# Epoch 00020: saving model to ./model/20-0.1635.hdf5
#
# Epoch 00021: saving model to ./model/21-0.1585.hdf5
#
# Epoch 00022: saving model to ./model/22-0.1562.hdf5
#
# Epoch 00023: saving model to ./model/23-0.1632.hdf5
#
# Epoch 00024: saving model to ./model/24-0.1505.hdf5
#
# Epoch 00025: saving model to ./model/25-0.1499.hdf5
#
# Epoch 00026: saving model to ./model/26-0.1438.hdf5
#
# Epoch 00027: saving model to ./model/27-0.1484.hdf5
#
# Epoch 00028: saving model to ./model/28-0.1363.hdf5
#
# Epoch 00029: saving model to ./model/29-0.1465.hdf5
#
# Epoch 00030: saving model to ./model/30-0.1313.hdf5
#
# Epoch 00031: saving model to ./model/31-0.1331.hdf5
#
# Epoch 00032: saving model to ./model/32-0.1310.hdf5
#
# Epoch 00033: saving model to ./model/33-0.1222.hdf5
#
# Epoch 00034: saving model to ./model/34-0.1204.hdf5
#
# Epoch 00035: saving model to ./model/35-0.1270.hdf5
#
# Epoch 00036: saving model to ./model/36-0.1178.hdf5
#
# Epoch 00037: saving model to ./model/37-0.1105.hdf5
#
# Epoch 00038: saving model to ./model/38-0.1100.hdf5
#
# Epoch 00039: saving model to ./model/39-0.1055.hdf5
#
# Epoch 00040: saving model to ./model/40-0.1118.hdf5
#
# Epoch 00041: saving model to ./model/41-0.1020.hdf5
#
# Epoch 00042: saving model to ./model/42-0.1035.hdf5
#
# Epoch 00043: saving model to ./model/43-0.1001.hdf5
#
# Epoch 00044: saving model to ./model/44-0.0974.hdf5
#
# Epoch 00045: saving model to ./model/45-0.0952.hdf5
#
# Epoch 00046: saving model to ./model/46-0.1029.hdf5
#
# Epoch 00047: saving model to ./model/47-0.1652.hdf5
#
# Epoch 00048: saving model to ./model/48-0.0950.hdf5
#
# Epoch 00049: saving model to ./model/49-0.0904.hdf5
#
# Epoch 00050: saving model to ./model/50-0.1022.hdf5
#
# Epoch 00051: saving model to ./model/51-0.0883.hdf5
#
# Epoch 00052: saving model to ./model/52-0.0900.hdf5
#
# Epoch 00053: saving model to ./model/53-0.0856.hdf5
#
# Epoch 00054: saving model to ./model/54-0.0852.hdf5
#
# Epoch 00055: saving model to ./model/55-0.0836.hdf5
#
# Epoch 00056: saving model to ./model/56-0.0923.hdf5
#
# Epoch 00057: saving model to ./model/57-0.0997.hdf5
#
# Epoch 00058: saving model to ./model/58-0.0813.hdf5
#
# Epoch 00059: saving model to ./model/59-0.0787.hdf5
#
# Epoch 00060: saving model to ./model/60-0.0860.hdf5
#
# Epoch 00061: saving model to ./model/61-0.0793.hdf5
#
# Epoch 00062: saving model to ./model/62-0.0777.hdf5
#
# Epoch 00063: saving model to ./model/63-0.0756.hdf5
#
# Epoch 00064: saving model to ./model/64-0.0848.hdf5
#
# Epoch 00065: saving model to ./model/65-0.0732.hdf5
#
# Epoch 00066: saving model to ./model/66-0.0756.hdf5
#
# Epoch 00067: saving model to ./model/67-0.0741.hdf5
#
# Epoch 00068: saving model to ./model/68-0.0718.hdf5
#
# Epoch 00069: saving model to ./model/69-0.0728.hdf5
#
# Epoch 00070: saving model to ./model/70-0.0711.hdf5
#
# Epoch 00071: saving model to ./model/71-0.0702.hdf5
#
# Epoch 00072: saving model to ./model/72-0.0726.hdf5
#
# Epoch 00073: saving model to ./model/73-0.0694.hdf5
#
# Epoch 00074: saving model to ./model/74-0.0678.hdf5
#
# Epoch 00075: saving model to ./model/75-0.0676.hdf5
#
# Epoch 00076: saving model to ./model/76-0.0730.hdf5
#
# Epoch 00077: saving model to ./model/77-0.0682.hdf5
#
# Epoch 00078: saving model to ./model/78-0.0661.hdf5
#
# Epoch 00079: saving model to ./model/79-0.0889.hdf5
#
# Epoch 00080: saving model to ./model/80-0.0661.hdf5
#
# Epoch 00081: saving model to ./model/81-0.0671.hdf5
#
# Epoch 00082: saving model to ./model/82-0.0704.hdf5
#
# Epoch 00083: saving model to ./model/83-0.0647.hdf5
#
# Epoch 00084: saving model to ./model/84-0.0682.hdf5
#
# Epoch 00085: saving model to ./model/85-0.0641.hdf5
#
# Epoch 00086: saving model to ./model/86-0.0787.hdf5
#
# Epoch 00087: saving model to ./model/87-0.0767.hdf5
#
# Epoch 00088: saving model to ./model/88-0.0652.hdf5
#
# Epoch 00089: saving model to ./model/89-0.0626.hdf5
#
# Epoch 00090: saving model to ./model/90-0.0642.hdf5
#
# Epoch 00091: saving model to ./model/91-0.0733.hdf5
#
# Epoch 00092: saving model to ./model/92-0.0690.hdf5
#
# Epoch 00093: saving model to ./model/93-0.0729.hdf5
#
# Epoch 00094: saving model to ./model/94-0.0627.hdf5
#
# Epoch 00095: saving model to ./model/95-0.0805.hdf5
#
# Epoch 00096: saving model to ./model/96-0.0614.hdf5
#
# Epoch 00097: saving model to ./model/97-0.0652.hdf5
#
# Epoch 00098: saving model to ./model/98-0.0615.hdf5
#
# Epoch 00099: saving model to ./model/99-0.0608.hdf5
#
# Epoch 00100: saving model to ./model/100-0.0645.hdf5
#
# Epoch 00101: saving model to ./model/101-0.0692.hdf5
#
# Epoch 00102: saving model to ./model/102-0.0626.hdf5
#
# Epoch 00103: saving model to ./model/103-0.0604.hdf5
#
# Epoch 00104: saving model to ./model/104-0.0617.hdf5
#
# Epoch 00105: saving model to ./model/105-0.0740.hdf5
#
# Epoch 00106: saving model to ./model/106-0.0638.hdf5
#
# Epoch 00107: saving model to ./model/107-0.0719.hdf5
#
# Epoch 00108: saving model to ./model/108-0.0666.hdf5
#
# Epoch 00109: saving model to ./model/109-0.0637.hdf5
#
# Epoch 00110: saving model to ./model/110-0.0596.hdf5
#
# Epoch 00111: saving model to ./model/111-0.0601.hdf5
#
# Epoch 00112: saving model to ./model/112-0.0580.hdf5
#
# Epoch 00113: saving model to ./model/113-0.0600.hdf5
#
# Epoch 00114: saving model to ./model/114-0.0614.hdf5
#
# Epoch 00115: saving model to ./model/115-0.0592.hdf5
#
# Epoch 00116: saving model to ./model/116-0.0633.hdf5
#
# Epoch 00117: saving model to ./model/117-0.0633.hdf5
#
# Epoch 00118: saving model to ./model/118-0.0838.hdf5
#
# Epoch 00119: saving model to ./model/119-0.0606.hdf5
#
# Epoch 00120: saving model to ./model/120-0.0581.hdf5
#
# Epoch 00121: saving model to ./model/121-0.0586.hdf5
#
# Epoch 00122: saving model to ./model/122-0.0583.hdf5
#
# Epoch 00123: saving model to ./model/123-0.0576.hdf5
#
# Epoch 00124: saving model to ./model/124-0.0622.hdf5
#
# Epoch 00125: saving model to ./model/125-0.0649.hdf5
#
# Epoch 00126: saving model to ./model/126-0.0582.hdf5
#
# Epoch 00127: saving model to ./model/127-0.0564.hdf5
#
# Epoch 00128: saving model to ./model/128-0.0640.hdf5
#
# Epoch 00129: saving model to ./model/129-0.0572.hdf5
#
# Epoch 00130: saving model to ./model/130-0.0606.hdf5
#
# Epoch 00131: saving model to ./model/131-0.0618.hdf5
#
# Epoch 00132: saving model to ./model/132-0.0561.hdf5
#
# Epoch 00133: saving model to ./model/133-0.0615.hdf5
#
# Epoch 00134: saving model to ./model/134-0.0594.hdf5
#
# Epoch 00135: saving model to ./model/135-0.0563.hdf5
#
# Epoch 00136: saving model to ./model/136-0.0557.hdf5
#
# Epoch 00137: saving model to ./model/137-0.0552.hdf5
#
# Epoch 00138: saving model to ./model/138-0.0696.hdf5
#
# Epoch 00139: saving model to ./model/139-0.0598.hdf5
#
# Epoch 00140: saving model to ./model/140-0.0555.hdf5
#
# Epoch 00141: saving model to ./model/141-0.0587.hdf5
#
# Epoch 00142: saving model to ./model/142-0.0557.hdf5
#
# Epoch 00143: saving model to ./model/143-0.0547.hdf5
#
# Epoch 00144: saving model to ./model/144-0.0580.hdf5
#
# Epoch 00145: saving model to ./model/145-0.0563.hdf5
#
# Epoch 00146: saving model to ./model/146-0.0561.hdf5
#
# Epoch 00147: saving model to ./model/147-0.0761.hdf5
#
# Epoch 00148: saving model to ./model/148-0.0579.hdf5
#
# Epoch 00149: saving model to ./model/149-0.1035.hdf5
#
# Epoch 00150: saving model to ./model/150-0.0618.hdf5
#
# Epoch 00151: saving model to ./model/151-0.0633.hdf5
#
# Epoch 00152: saving model to ./model/152-0.0629.hdf5
#
# Epoch 00153: saving model to ./model/153-0.0605.hdf5
#
# Epoch 00154: saving model to ./model/154-0.0610.hdf5
#
# Epoch 00155: saving model to ./model/155-0.0576.hdf5
#
# Epoch 00156: saving model to ./model/156-0.0566.hdf5
#
# Epoch 00157: saving model to ./model/157-0.0576.hdf5
#
# Epoch 00158: saving model to ./model/158-0.0562.hdf5
#
# Epoch 00159: saving model to ./model/159-0.0553.hdf5
#
# Epoch 00160: saving model to ./model/160-0.0696.hdf5
#
# Epoch 00161: saving model to ./model/161-0.0600.hdf5
#
# Epoch 00162: saving model to ./model/162-0.0546.hdf5
#
# Epoch 00163: saving model to ./model/163-0.0584.hdf5
#
# Epoch 00164: saving model to ./model/164-0.0565.hdf5
#
# Epoch 00165: saving model to ./model/165-0.0572.hdf5
#
# Epoch 00166: saving model to ./model/166-0.0543.hdf5
#
# Epoch 00167: saving model to ./model/167-0.0606.hdf5
#
# Epoch 00168: saving model to ./model/168-0.0563.hdf5
#
# Epoch 00169: saving model to ./model/169-0.0636.hdf5
#
# Epoch 00170: saving model to ./model/170-0.0635.hdf5
#
# Epoch 00171: saving model to ./model/171-0.0540.hdf5
#
# Epoch 00172: saving model to ./model/172-0.0553.hdf5
#
# Epoch 00173: saving model to ./model/173-0.0577.hdf5
#
# Epoch 00174: saving model to ./model/174-0.0579.hdf5
#
# Epoch 00175: saving model to ./model/175-0.0543.hdf5
#
# Epoch 00176: saving model to ./model/176-0.0539.hdf5
#
# Epoch 00177: saving model to ./model/177-0.0591.hdf5
#
# Epoch 00178: saving model to ./model/178-0.0555.hdf5
#
# Epoch 00179: saving model to ./model/179-0.0581.hdf5
#
# Epoch 00180: saving model to ./model/180-0.0611.hdf5
#
# Epoch 00181: saving model to ./model/181-0.0571.hdf5
#
# Epoch 00182: saving model to ./model/182-0.0599.hdf5
#
# Epoch 00183: saving model to ./model/183-0.0657.hdf5
#
# Epoch 00184: saving model to ./model/184-0.0544.hdf5
#
# Epoch 00185: saving model to ./model/185-0.0564.hdf5
#
# Epoch 00186: saving model to ./model/186-0.0644.hdf5
#
# Epoch 00187: saving model to ./model/187-0.0545.hdf5
#
# Epoch 00188: saving model to ./model/188-0.0647.hdf5
#
# Epoch 00189: saving model to ./model/189-0.0539.hdf5
#
# Epoch 00190: saving model to ./model/190-0.0575.hdf5
#
# Epoch 00191: saving model to ./model/191-0.0594.hdf5
#
# Epoch 00192: saving model to ./model/192-0.0534.hdf5
#
# Epoch 00193: saving model to ./model/193-0.0544.hdf5
#
# Epoch 00194: saving model to ./model/194-0.0553.hdf5
#
# Epoch 00195: saving model to ./model/195-0.0569.hdf5
#
# Epoch 00196: saving model to ./model/196-0.0596.hdf5
#
# Epoch 00197: saving model to ./model/197-0.0644.hdf5
#
# Epoch 00198: saving model to ./model/198-0.0738.hdf5
#
# Epoch 00199: saving model to ./model/199-0.0594.hdf5
#
# Epoch 00200: saving model to ./model/200-0.0535.hdf5
